# %% [markdown]
# ## Предметная область: Игра Dota 2
#
# [Dota 2](https://ru.wikipedia.org/wiki/Dota_2) — многопользовательская компьютерная игра жанра [MOBA](https://ru.wikipedia.org/wiki/MOBA). Игроки играют между собой матчи. В каждом матче участвует две команды, 5 человек в каждой. Одна команда играет за светлую сторону (The Radiant), другая — за тёмную (The Dire). Цель каждой команды — уничтожить главное здание базы противника (трон).
#
# Существуют [разные режимы игры](http://dota2.gamepedia.com/Game_modes/ru), мы будем рассматривать режим [Captain's Mode](http://dota2.gamepedia.com/Game_modes/ru#Captain.27s_Mode), в формате которого происходит большая часть киберспортивных мероприятий по Dota 2.
#
# ### Как проходит матч
#
# #### 1. Игроки выбирают героев
#
# Всего в игре чуть более 100 различных героев (персонажей). В начале игры, команды в определенном порядке выбирают героев себе и запрещают выбирать определенных героев противнику (баны). Каждый игрок будет управлять одним героем, в рамках одного матча не может быть несколько одинаковых героев.  Герои различаются между собой своими характеристиками и способностями. От комбинации выбранных героев во многом зависит успех команды.
#
# ![](http://imgur.com/XFr4HYE.jpg)
#
# #### 2. Основная часть
#
# Игроки могут получать золото и опыт за убийство чужих героев или прочих юнитов. Накопленный опыт влияет на уровень героя, который в свою очередь позволяет улучшать способности. За накопленное золото игроки покупают предметы, которые улучшают характеристики героев или дают им новые способности.
#
# После смерти герой отправляется в "таверну" и возрождается только по прошествии некоторого времени, таким образом команда на некоторое время теряет игрока, однако игрок может досрочно выкупить героя из таверны за определенную сумму золота.
#
# В течение игры команды развивают своих героев, обороняют свою часть поля и нападают на вражескую.
#
# ![](http://imgur.com/5b0SlQb.jpg)
#
# #### 3. Конец игры
#
# Игра заканчивается, когда одна из команд разрушет определенное число "башен" противника и уничтожает трон.
#
# ![](http://imgur.com/Du79Kzf.jpg)

# %% [markdown]
# ## Задача: предсказание победы по данным о первых 5 минутах игры
#
# По первым 5 минутам игры предсказать, какая из команд победит: Radiant или Dire?
# `Метрика качества - площадь под ROC-кривой.`

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import cross_val_score, KFold
from catboost import CatBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler


import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('features.csv', index_col="match_id")
test = pd.read_csv('features_test.csv', index_col="match_id")

# %% [markdown]
# #### Описание признаков в таблице
#
# - `match_id`: идентификатор матча в наборе данных
# - `start_time`: время начала матча (unixtime)
# - `lobby_type`: тип комнаты, в которой собираются игроки (расшифровка в `dictionaries/lobbies.csv`)
# - Наборы признаков для каждого игрока (игроки команды Radiant — префикс `rN`, Dire — `dN`):
#     - `r1_hero`: герой игрока (расшифровка в dictionaries/heroes.csv)
#     - `r1_level`: максимальный достигнутый уровень героя (за первые 5 игровых минут)
#     - `r1_xp`: максимальный полученный опыт
#     - `r1_gold`: достигнутая ценность героя
#     - `r1_lh`: число убитых юнитов
#     - `r1_kills`: число убитых игроков
#     - `r1_deaths`: число смертей героя
#     - `r1_items`: число купленных предметов
# - Признаки события "первая кровь" (first blood). Если событие "первая кровь" не успело произойти за первые 5 минут, то признаки принимают пропущенное значение
#     - `first_blood_time`: игровое время первой крови
#     - `first_blood_team`: команда, совершившая первую кровь (0 — Radiant, 1 — Dire)
#     - `first_blood_player1`: игрок, причастный к событию
#     - `first_blood_player2`: второй игрок, причастный к событию
# - Признаки для каждой команды (префиксы `radiant_` и `dire_`)
#     - `radiant_bottle_time`: время первого приобретения командой предмета "bottle"
#     - `radiant_courier_time`: время приобретения предмета "courier"
#     - `radiant_flying_courier_time`: время приобретения предмета "flying_courier"
#     - `radiant_tpscroll_count`: число предметов "tpscroll" за первые 5 минут
#     - `radiant_boots_count`: число предметов "boots"
#     - `radiant_ward_observer_count`: число предметов "ward_observer"
#     - `radiant_ward_sentry_count`: число предметов "ward_sentry"
#     - `radiant_first_ward_time`: время установки командой первого "наблюдателя", т.е. предмета, который позволяет видеть часть игрового поля
# - Итог матча (данные поля отсутствуют в тестовой выборке, поскольку содержат информацию, выходящую за пределы первых 5 минут матча)
#     - `duration`: длительность
#     - `radiant_win`: 1, если победила команда Radiant, 0 — иначе
#     - Состояние башен и барраков к концу матча (см. описание полей набора данных)
#         - `tower_status_radiant`
#         - `tower_status_dire`
#         - `barracks_status_radiant`
#         - `barracks_status_dire`

# %%
train.head()
# Out:
#           start_time  lobby_type  r1_hero  r1_level  r1_xp  r1_gold  r1_lh  \
# match_id
# 0         1430198770           7       11         5   2098     1489     20
# 1         1430220345           0       42         4   1188     1033      9
# 2         1430227081           7       33         4   1319     1270     22
# 3         1430263531           1       29         4   1779     1056     14
# 4         1430282290           7       13         4   1431     1090      8
#
#           r1_kills  r1_deaths  r1_items  ...  dire_boots_count  \
# match_id                                 ...
# 0                0          0         7  ...                 4
# 1                0          1        12  ...                 4
# 2                0          0        12  ...                 4
# 3                0          0         5  ...                 4
# 4                1          0         8  ...                 3
#
#           dire_ward_observer_count  dire_ward_sentry_count  \
# match_id
# 0                                2                       2
# 1                                3                       1
# 2                                3                       1
# 3                                2                       0
# 4                                3                       0
#
#           dire_first_ward_time  duration  radiant_win  tower_status_radiant  \
# match_id
# 0                        -52.0      2874            1                  1796
# 1                         -5.0      2463            1                  1974
# 2                         13.0      2130            0                     0
# 3                         27.0      1459            0                  1920
# 4                        -16.0      2449            0                     4
#
#           tower_status_dire  barracks_status_radiant  barracks_status_dire
# match_id
# 0                         0                       51                     0
# 1                         0                       63                     1
# 2                      1830                        0                    63
# 3                      2047                       50                    63
# 4                      1974                        3                    63
#
# [5 rows x 108 columns]

# %%
test.head()
# Out:
#           start_time  lobby_type  r1_hero  r1_level  r1_xp  r1_gold  r1_lh  \
# match_id
# 6         1430287923           0       93         4   1103     1089      8
# 7         1430293357           1       20         2    556      570      1
# 10        1430301774           1      112         2    751      808      1
# 13        1430323933           1       27         3    708      903      1
# 16        1430331112           1       39         4   1259      661      4
#
#           r1_kills  r1_deaths  r1_items  ...  radiant_ward_sentry_count  \
# match_id                                 ...
# 6                0          1         9  ...                          0
# 7                0          0         9  ...                          2
# 10               0          0        13  ...                          1
# 13               1          1        11  ...                          2
# 16               0          0         9  ...                          0
#
#           radiant_first_ward_time  dire_bottle_time  dire_courier_time  \
# match_id
# 6                            12.0             247.0              -86.0
# 7                           -29.0             168.0              -54.0
# 10                          -22.0              46.0              -87.0
# 13                          -49.0              30.0              -89.0
# 16                           36.0             180.0              -86.0
#
#           dire_flying_courier_time  dire_tpscroll_count  dire_boots_count  \
# match_id
# 6                            272.0                    3                 4
# 7                              NaN                    3                 2
# 10                           186.0                    1                 3
# 13                           210.0                    3                 4
# 16                           180.0                    1                 3
#
#           dire_ward_observer_count  dire_ward_sentry_count  \
# match_id
# 6                                2                       0
# 7                                2                       1
# 10                               3                       0
# 13                               2                       1
# 16                               2                       1
#
#           dire_first_ward_time
# match_id
# 6                        118.0
# 7                         16.0
# 10                       -34.0
# 13                       -26.0
# 16                       -33.0
#
# [5 rows x 102 columns]

# %%
train.shape
# Out:
# (97230, 108)

# %% [markdown]
# > - Тренировочная выборка содержит признаки, которых нет в тестовой - это характеристики матча, которые не известны в первые пять минут (продолжительность матча, состояние башен к концу матча) - их нужно удалить.
# - Признак 'radiant_win' является таргетом.

# %% [markdown]
# #### Заполнение пропусков

# %%
train.isna().sum().sort_values(ascending=False)[:15]
# Out:
# first_blood_player2            43987
# radiant_flying_courier_time    27479
# dire_flying_courier_time       26098
# first_blood_player1            19553
# first_blood_team               19553
# first_blood_time               19553
# dire_bottle_time               16143
# radiant_bottle_time            15691
# radiant_first_ward_time         1836
# dire_first_ward_time            1826
# radiant_courier_time             692
# dire_courier_time                676
# r4_lh                              0
# r4_kills                           0
# r4_deaths                          0
# dtype: int64

# %% [markdown]
# > Большинство пропусков находятся в категории first_blood. В описании признаков указано, что если событие "первая кровь" не успело произойти за первые 5 минут, то признаки принимают пропущенное значение. Поэтому вместо пропущенных значений укажем информацию об остутствии события.

# %%
train.fillna(0, inplace=True)
test.fillna(0, inplace=True)

# %%
target = train['radiant_win']

# %%
extra = set(train.columns) - set(test.columns) # найдем лишние колонки
features = train.drop(extra, axis=1) # и удалим их

# %% [markdown]
# ### Градиентный бустинг

# %% [markdown]
# #### Gradient Boosting Classifier

# %%
cv = KFold(n_splits=5, shuffle=True)
best_score = 0
for est in [10, 20, 30]:
    GBclf = GradientBoostingClassifier(n_estimators=est, random_state=1)
    score = cross_val_score(GBclf, features, target, cv=cv, scoring='roc_auc').mean()
    if score > best_score:
        print("Кол-во деревьев", est, ":", score)
        best_score = score
        best_model_GB = GBclf
# Out:
# Кол-во деревьев 10 : 0.6651865606019264
# Кол-во деревьев 20 : 0.682310514245471
# Кол-во деревьев 30 : 0.6898931106775492

# %%
# %%time
GBclf = GradientBoostingClassifier(n_estimators=30, random_state=1)
score = cross_val_score(GBclf, features, target, cv=cv, scoring='roc_auc').mean()
# Out:
# Wall time: 5min 59s

# %% [markdown]
# #### Cat Boosting Classifier

# %%
cv = KFold(shuffle=True)
cat_model = CatBoostClassifier(eval_metric='AUC')

score = cross_val_score(cat_model, features, target, cv=cv, scoring='roc_auc').mean()
# Out:
# Learning rate set to 0.066122
# 0:	total: 240ms	remaining: 3m 59s
# 1:	total: 366ms	remaining: 3m 2s
# 2:	total: 503ms	remaining: 2m 47s
# 3:	total: 629ms	remaining: 2m 36s
# 4:	total: 787ms	remaining: 2m 36s
# 5:	total: 939ms	remaining: 2m 35s
# 6:	total: 1.16s	remaining: 2m 44s
# 7:	total: 1.33s	remaining: 2m 44s
# 8:	total: 1.48s	remaining: 2m 42s
# 9:	total: 1.59s	remaining: 2m 37s
# 10:	total: 1.73s	remaining: 2m 35s
# 11:	total: 1.86s	remaining: 2m 33s
# 12:	total: 2s	remaining: 2m 31s
# 13:	total: 2.17s	remaining: 2m 32s
# 14:	total: 2.37s	remaining: 2m 35s
# 15:	total: 2.48s	remaining: 2m 32s
# 16:	total: 2.61s	remaining: 2m 31s
# 17:	total: 2.74s	remaining: 2m 29s
# 18:	total: 2.9s	remaining: 2m 29s
# 19:	total: 3.02s	remaining: 2m 28s
# 20:	total: 3.18s	remaining: 2m 28s
# 21:	total: 3.36s	remaining: 2m 29s
# 22:	total: 3.53s	remaining: 2m 30s
# 23:	total: 3.64s	remaining: 2m 28s
# 24:	total: 3.78s	remaining: 2m 27s
# 25:	total: 3.92s	remaining: 2m 26s
# 26:	total: 4.05s	remaining: 2m 26s
# 27:	total: 4.18s	remaining: 2m 25s
# 28:	total: 4.36s	remaining: 2m 26s
# 29:	total: 4.52s	remaining: 2m 26s
# 30:	total: 4.68s	remaining: 2m 26s
# 31:	total: 4.83s	remaining: 2m 26s
# 32:	total: 4.99s	remaining: 2m 26s
# 33:	total: 5.12s	remaining: 2m 25s
# 34:	total: 5.26s	remaining: 2m 25s
# 35:	total: 5.39s	remaining: 2m 24s
# 36:	total: 5.57s	remaining: 2m 24s
# 37:	total: 5.73s	remaining: 2m 24s
# 38:	total: 5.88s	remaining: 2m 24s
# 39:	total: 6s	remaining: 2m 24s
# 40:	total: 6.17s	remaining: 2m 24s
# 41:	total: 6.3s	remaining: 2m 23s
# 42:	total: 6.45s	remaining: 2m 23s
# 43:	total: 6.62s	remaining: 2m 23s
# 44:	total: 6.81s	remaining: 2m 24s
# 45:	total: 6.93s	remaining: 2m 23s
# 46:	total: 7.08s	remaining: 2m 23s
# 47:	total: 7.19s	remaining: 2m 22s
# 48:	total: 7.34s	remaining: 2m 22s
# 49:	total: 7.48s	remaining: 2m 22s
# 50:	total: 7.64s	remaining: 2m 22s
# 51:	total: 7.8s	remaining: 2m 22s
# 52:	total: 7.99s	remaining: 2m 22s
# 53:	total: 8.12s	remaining: 2m 22s
# 54:	total: 8.26s	remaining: 2m 21s
# 55:	total: 8.38s	remaining: 2m 21s
# 56:	total: 8.51s	remaining: 2m 20s
# 57:	total: 8.63s	remaining: 2m 20s
# 58:	total: 8.82s	remaining: 2m 20s
# 59:	total: 8.98s	remaining: 2m 20s
# 60:	total: 9.15s	remaining: 2m 20s
# 61:	total: 9.28s	remaining: 2m 20s
# 62:	total: 9.43s	remaining: 2m 20s
# 63:	total: 9.54s	remaining: 2m 19s
# 64:	total: 9.68s	remaining: 2m 19s
# 65:	total: 9.83s	remaining: 2m 19s
# 66:	total: 10s	remaining: 2m 19s
# 67:	total: 10.2s	remaining: 2m 19s
# 68:	total: 10.3s	remaining: 2m 19s
# 69:	total: 10.4s	remaining: 2m 18s
# 70:	total: 10.6s	remaining: 2m 18s
# 71:	total: 10.7s	remaining: 2m 17s
# 72:	total: 10.8s	remaining: 2m 17s
# 73:	total: 11s	remaining: 2m 17s
# 74:	total: 11.2s	remaining: 2m 18s
# 75:	total: 11.3s	remaining: 2m 17s
# 76:	total: 11.5s	remaining: 2m 17s
# 77:	total: 11.6s	remaining: 2m 17s
# 78:	total: 11.8s	remaining: 2m 17s
# 79:	total: 11.9s	remaining: 2m 16s
# 80:	total: 12.1s	remaining: 2m 16s
# 81:	total: 12.2s	remaining: 2m 16s
# 82:	total: 12.4s	remaining: 2m 16s
# 83:	total: 12.5s	remaining: 2m 16s
# 84:	total: 12.6s	remaining: 2m 16s
# 85:	total: 12.8s	remaining: 2m 15s
# 86:	total: 12.9s	remaining: 2m 15s
# 87:	total: 13s	remaining: 2m 15s
# 88:	total: 13.2s	remaining: 2m 15s
# 89:	total: 13.4s	remaining: 2m 15s
# 90:	total: 13.5s	remaining: 2m 15s
# 91:	total: 13.7s	remaining: 2m 14s
# 92:	total: 13.8s	remaining: 2m 14s
# 93:	total: 13.9s	remaining: 2m 14s
# 94:	total: 14.1s	remaining: 2m 14s
# 95:	total: 14.2s	remaining: 2m 13s
# 96:	total: 14.4s	remaining: 2m 14s
# 97:	total: 14.6s	remaining: 2m 14s
# 98:	total: 14.7s	remaining: 2m 14s
# 99:	total: 14.9s	remaining: 2m 13s
# 100:	total: 15s	remaining: 2m 13s
# 101:	total: 15.2s	remaining: 2m 13s
# 102:	total: 15.3s	remaining: 2m 13s
# 103:	total: 15.4s	remaining: 2m 13s
# 104:	total: 15.6s	remaining: 2m 13s
# 105:	total: 15.8s	remaining: 2m 12s
# 106:	total: 15.9s	remaining: 2m 12s
# 107:	total: 16.1s	remaining: 2m 12s
# 108:	total: 16.2s	remaining: 2m 12s
# 109:	total: 16.3s	remaining: 2m 12s
# 110:	total: 16.5s	remaining: 2m 12s
# 111:	total: 16.6s	remaining: 2m 11s
# 112:	total: 16.8s	remaining: 2m 12s
# 113:	total: 16.9s	remaining: 2m 11s
# 114:	total: 17.1s	remaining: 2m 11s
# 115:	total: 17.2s	remaining: 2m 11s
# 116:	total: 17.4s	remaining: 2m 11s
# 117:	total: 17.5s	remaining: 2m 10s
# 118:	total: 17.7s	remaining: 2m 11s
# 119:	total: 17.9s	remaining: 2m 11s
# 120:	total: 18s	remaining: 2m 10s
# 121:	total: 18.1s	remaining: 2m 10s
# 122:	total: 18.3s	remaining: 2m 10s
# 123:	total: 18.4s	remaining: 2m 9s
# 124:	total: 18.5s	remaining: 2m 9s
# 125:	total: 18.6s	remaining: 2m 9s
# 126:	total: 18.9s	remaining: 2m 9s
# 127:	total: 19s	remaining: 2m 9s
# 128:	total: 19.1s	remaining: 2m 9s
# 129:	total: 19.3s	remaining: 2m 8s
# 130:	total: 19.4s	remaining: 2m 8s
# 131:	total: 19.5s	remaining: 2m 8s
# 132:	total: 19.7s	remaining: 2m 8s
# 133:	total: 19.8s	remaining: 2m 8s
# 134:	total: 20s	remaining: 2m 8s
# 135:	total: 20.1s	remaining: 2m 7s
# 136:	total: 20.3s	remaining: 2m 7s
# 137:	total: 20.5s	remaining: 2m 8s
# 138:	total: 20.7s	remaining: 2m 8s
# 139:	total: 21s	remaining: 2m 9s
# 140:	total: 21.3s	remaining: 2m 9s
# 141:	total: 21.6s	remaining: 2m 10s
# 142:	total: 21.9s	remaining: 2m 11s
# 143:	total: 22.1s	remaining: 2m 11s
# 144:	total: 22.4s	remaining: 2m 12s
# 145:	total: 22.6s	remaining: 2m 11s
# 146:	total: 22.8s	remaining: 2m 12s
# 147:	total: 23.1s	remaining: 2m 12s
# 148:	total: 23.3s	remaining: 2m 13s
# 149:	total: 23.6s	remaining: 2m 13s
# 150:	total: 23.8s	remaining: 2m 14s
# 151:	total: 24s	remaining: 2m 13s
# 152:	total: 24.1s	remaining: 2m 13s
# 153:	total: 24.2s	remaining: 2m 13s
# 154:	total: 24.4s	remaining: 2m 12s
# 155:	total: 24.5s	remaining: 2m 12s
# 156:	total: 24.7s	remaining: 2m 12s
# 157:	total: 24.8s	remaining: 2m 12s
# 158:	total: 25s	remaining: 2m 12s
# 159:	total: 25.1s	remaining: 2m 11s
# 160:	total: 25.2s	remaining: 2m 11s
# 161:	total: 25.4s	remaining: 2m 11s
# 162:	total: 25.6s	remaining: 2m 11s
# 163:	total: 25.8s	remaining: 2m 11s
# 164:	total: 26s	remaining: 2m 11s
# 165:	total: 26.1s	remaining: 2m 11s
# 166:	total: 26.2s	remaining: 2m 10s
# 167:	total: 26.4s	remaining: 2m 10s
# 168:	total: 26.5s	remaining: 2m 10s
# 169:	total: 26.7s	remaining: 2m 10s
# 170:	total: 26.8s	remaining: 2m 9s
# 171:	total: 27s	remaining: 2m 9s
# 172:	total: 27.1s	remaining: 2m 9s
# 173:	total: 27.3s	remaining: 2m 9s
# 174:	total: 27.4s	remaining: 2m 9s
# 175:	total: 27.5s	remaining: 2m 8s
# 176:	total: 27.7s	remaining: 2m 8s
# 177:	total: 27.8s	remaining: 2m 8s
# 178:	total: 28s	remaining: 2m 8s
# 179:	total: 28.2s	remaining: 2m 8s
# 180:	total: 28.3s	remaining: 2m 8s
# 181:	total: 28.5s	remaining: 2m 8s
# 182:	total: 28.6s	remaining: 2m 7s
# 183:	total: 28.7s	remaining: 2m 7s
# 184:	total: 28.9s	remaining: 2m 7s
# 185:	total: 29s	remaining: 2m 6s
# 186:	total: 29.1s	remaining: 2m 6s
# 187:	total: 29.3s	remaining: 2m 6s
# 188:	total: 29.5s	remaining: 2m 6s
# 189:	total: 29.6s	remaining: 2m 6s
# 190:	total: 29.7s	remaining: 2m 5s
# 191:	total: 29.9s	remaining: 2m 5s
# 192:	total: 30s	remaining: 2m 5s
# 193:	total: 30.1s	remaining: 2m 5s
# 194:	total: 30.3s	remaining: 2m 4s
# 195:	total: 30.5s	remaining: 2m 5s
# 196:	total: 30.6s	remaining: 2m 4s
# 197:	total: 30.7s	remaining: 2m 4s
# 198:	total: 30.9s	remaining: 2m 4s
# 199:	total: 31s	remaining: 2m 4s
# 200:	total: 31.1s	remaining: 2m 3s
# 201:	total: 31.3s	remaining: 2m 3s
# 202:	total: 31.4s	remaining: 2m 3s
# 203:	total: 31.7s	remaining: 2m 3s
# 204:	total: 31.8s	remaining: 2m 3s
# 205:	total: 31.9s	remaining: 2m 3s
# 206:	total: 32s	remaining: 2m 2s
# 207:	total: 32.2s	remaining: 2m 2s
# 208:	total: 32.3s	remaining: 2m 2s
# 209:	total: 32.4s	remaining: 2m 1s
# 210:	total: 32.5s	remaining: 2m 1s
# 211:	total: 32.8s	remaining: 2m 1s
# 212:	total: 32.9s	remaining: 2m 1s
# 213:	total: 33s	remaining: 2m 1s
# 214:	total: 33.2s	remaining: 2m 1s
# 215:	total: 33.3s	remaining: 2m
# 216:	total: 33.4s	remaining: 2m
# 217:	total: 33.6s	remaining: 2m
# 218:	total: 33.7s	remaining: 2m
# 219:	total: 33.9s	remaining: 2m
# 220:	total: 34s	remaining: 1m 59s
# 221:	total: 34.1s	remaining: 1m 59s
# 222:	total: 34.3s	remaining: 1m 59s
# 223:	total: 34.4s	remaining: 1m 59s
# 224:	total: 34.6s	remaining: 1m 59s
# 225:	total: 34.7s	remaining: 1m 58s
# 226:	total: 34.8s	remaining: 1m 58s
# 227:	total: 35s	remaining: 1m 58s
# 228:	total: 35.2s	remaining: 1m 58s
# 229:	total: 35.3s	remaining: 1m 58s
# 230:	total: 35.4s	remaining: 1m 57s
# 231:	total: 35.6s	remaining: 1m 57s
# 232:	total: 35.7s	remaining: 1m 57s
# 233:	total: 35.9s	remaining: 1m 57s
# 234:	total: 36s	remaining: 1m 57s
# 235:	total: 36.2s	remaining: 1m 57s
# 236:	total: 36.3s	remaining: 1m 56s
# 237:	total: 36.4s	remaining: 1m 56s
# 238:	total: 36.6s	remaining: 1m 56s
# 239:	total: 36.7s	remaining: 1m 56s
# 240:	total: 36.8s	remaining: 1m 55s
# 241:	total: 37s	remaining: 1m 55s
# 242:	total: 37.1s	remaining: 1m 55s
# 243:	total: 37.2s	remaining: 1m 55s
# 244:	total: 37.4s	remaining: 1m 55s
# 245:	total: 37.6s	remaining: 1m 55s
# 246:	total: 37.7s	remaining: 1m 55s
# 247:	total: 37.8s	remaining: 1m 54s
# 248:	total: 38s	remaining: 1m 54s
# 249:	total: 38.1s	remaining: 1m 54s
# 250:	total: 38.2s	remaining: 1m 54s
# 251:	total: 38.4s	remaining: 1m 53s
# 252:	total: 38.6s	remaining: 1m 53s
# 253:	total: 38.8s	remaining: 1m 53s
# 254:	total: 38.9s	remaining: 1m 53s
# 255:	total: 39s	remaining: 1m 53s
# 256:	total: 39.1s	remaining: 1m 53s
# 257:	total: 39.3s	remaining: 1m 52s
# 258:	total: 39.4s	remaining: 1m 52s
# 259:	total: 39.5s	remaining: 1m 52s
# 260:	total: 39.8s	remaining: 1m 52s
# 261:	total: 39.9s	remaining: 1m 52s
# 262:	total: 40s	remaining: 1m 52s
# 263:	total: 40.2s	remaining: 1m 52s
# 264:	total: 40.3s	remaining: 1m 51s
# 265:	total: 40.5s	remaining: 1m 51s
# 266:	total: 40.6s	remaining: 1m 51s
# 267:	total: 40.9s	remaining: 1m 51s
# 268:	total: 41s	remaining: 1m 51s
# 269:	total: 41.2s	remaining: 1m 51s
# 270:	total: 41.3s	remaining: 1m 51s
# 271:	total: 41.5s	remaining: 1m 50s
# 272:	total: 41.6s	remaining: 1m 50s
# 273:	total: 41.8s	remaining: 1m 50s
# 274:	total: 42.1s	remaining: 1m 50s
# 275:	total: 42.2s	remaining: 1m 50s
# 276:	total: 42.3s	remaining: 1m 50s
# 277:	total: 42.4s	remaining: 1m 50s
# 278:	total: 42.6s	remaining: 1m 50s
# 279:	total: 42.7s	remaining: 1m 49s
# 280:	total: 42.8s	remaining: 1m 49s
# 281:	total: 43s	remaining: 1m 49s
# 282:	total: 43.1s	remaining: 1m 49s
# 283:	total: 43.3s	remaining: 1m 49s
# 284:	total: 43.4s	remaining: 1m 48s
# 285:	total: 43.5s	remaining: 1m 48s
# 286:	total: 43.7s	remaining: 1m 48s
# 287:	total: 43.9s	remaining: 1m 48s
# 288:	total: 44s	remaining: 1m 48s
# 289:	total: 44.3s	remaining: 1m 48s
# 290:	total: 44.5s	remaining: 1m 48s
# 291:	total: 44.7s	remaining: 1m 48s
# 292:	total: 44.9s	remaining: 1m 48s
# 293:	total: 45s	remaining: 1m 48s
# 294:	total: 45.2s	remaining: 1m 48s
# 295:	total: 45.4s	remaining: 1m 48s
# 296:	total: 45.7s	remaining: 1m 48s
# 297:	total: 45.9s	remaining: 1m 48s
# 298:	total: 46.1s	remaining: 1m 48s
# 299:	total: 46.2s	remaining: 1m 47s
# 300:	total: 46.4s	remaining: 1m 47s
# 301:	total: 46.5s	remaining: 1m 47s
# 302:	total: 46.7s	remaining: 1m 47s
# 303:	total: 46.8s	remaining: 1m 47s
# 304:	total: 47s	remaining: 1m 47s
# 305:	total: 47.1s	remaining: 1m 46s
# 306:	total: 47.2s	remaining: 1m 46s
# 307:	total: 47.3s	remaining: 1m 46s
# 308:	total: 47.5s	remaining: 1m 46s
# 309:	total: 47.6s	remaining: 1m 45s
# 310:	total: 47.8s	remaining: 1m 45s
# 311:	total: 47.9s	remaining: 1m 45s
# 312:	total: 48.1s	remaining: 1m 45s
# 313:	total: 48.2s	remaining: 1m 45s
# 314:	total: 48.3s	remaining: 1m 45s
# 315:	total: 48.4s	remaining: 1m 44s
# 316:	total: 48.6s	remaining: 1m 44s
# 317:	total: 48.7s	remaining: 1m 44s
# 318:	total: 48.9s	remaining: 1m 44s
# 319:	total: 49.1s	remaining: 1m 44s
# 320:	total: 49.2s	remaining: 1m 44s
# 321:	total: 49.3s	remaining: 1m 43s
# 322:	total: 49.4s	remaining: 1m 43s
# 323:	total: 49.6s	remaining: 1m 43s
# 324:	total: 49.7s	remaining: 1m 43s
# 325:	total: 49.9s	remaining: 1m 43s
# 326:	total: 50s	remaining: 1m 42s
# 327:	total: 50.2s	remaining: 1m 42s
# 328:	total: 50.4s	remaining: 1m 42s
# 329:	total: 50.5s	remaining: 1m 42s
# 330:	total: 50.6s	remaining: 1m 42s
# 331:	total: 50.7s	remaining: 1m 42s
# 332:	total: 50.9s	remaining: 1m 41s
# 333:	total: 51s	remaining: 1m 41s
# 334:	total: 51.1s	remaining: 1m 41s
# 335:	total: 51.3s	remaining: 1m 41s
# 336:	total: 51.5s	remaining: 1m 41s
# 337:	total: 51.6s	remaining: 1m 41s
# 338:	total: 51.7s	remaining: 1m 40s
# 339:	total: 51.9s	remaining: 1m 40s
# 340:	total: 52s	remaining: 1m 40s
# 341:	total: 52.1s	remaining: 1m 40s
# 342:	total: 52.3s	remaining: 1m 40s
# 343:	total: 52.5s	remaining: 1m 40s
# 344:	total: 52.6s	remaining: 1m 39s
# 345:	total: 52.7s	remaining: 1m 39s
# 346:	total: 52.9s	remaining: 1m 39s
# 347:	total: 53s	remaining: 1m 39s
# 348:	total: 53.1s	remaining: 1m 39s
# 349:	total: 53.3s	remaining: 1m 38s
# 350:	total: 53.4s	remaining: 1m 38s
# 351:	total: 53.6s	remaining: 1m 38s
# 352:	total: 53.8s	remaining: 1m 38s
# 353:	total: 53.9s	remaining: 1m 38s
# 354:	total: 54s	remaining: 1m 38s
# 355:	total: 54.2s	remaining: 1m 37s
# 356:	total: 54.3s	remaining: 1m 37s
# 357:	total: 54.4s	remaining: 1m 37s
# 358:	total: 54.6s	remaining: 1m 37s
# 359:	total: 54.8s	remaining: 1m 37s
# 360:	total: 54.9s	remaining: 1m 37s
# 361:	total: 55s	remaining: 1m 37s
# 362:	total: 55.2s	remaining: 1m 36s
# 363:	total: 55.3s	remaining: 1m 36s
# 364:	total: 55.4s	remaining: 1m 36s
# 365:	total: 55.6s	remaining: 1m 36s
# 366:	total: 55.7s	remaining: 1m 36s
# 367:	total: 56s	remaining: 1m 36s
# 368:	total: 56.1s	remaining: 1m 35s
# 369:	total: 56.2s	remaining: 1m 35s
# 370:	total: 56.4s	remaining: 1m 35s
# 371:	total: 56.5s	remaining: 1m 35s
# 372:	total: 56.6s	remaining: 1m 35s
# 373:	total: 56.8s	remaining: 1m 35s
# 374:	total: 56.9s	remaining: 1m 34s
# 375:	total: 57.1s	remaining: 1m 34s
# 376:	total: 57.3s	remaining: 1m 34s
# 377:	total: 57.5s	remaining: 1m 34s
# 378:	total: 57.6s	remaining: 1m 34s
# 379:	total: 57.7s	remaining: 1m 34s
# 380:	total: 57.9s	remaining: 1m 34s
# 381:	total: 58s	remaining: 1m 33s
# 382:	total: 58.2s	remaining: 1m 33s
# 383:	total: 58.4s	remaining: 1m 33s
# 384:	total: 58.5s	remaining: 1m 33s
# 385:	total: 58.6s	remaining: 1m 33s
# 386:	total: 58.7s	remaining: 1m 33s
# 387:	total: 58.9s	remaining: 1m 32s
# 388:	total: 59s	remaining: 1m 32s
# 389:	total: 59.1s	remaining: 1m 32s
# 390:	total: 59.3s	remaining: 1m 32s
# 391:	total: 59.5s	remaining: 1m 32s
# 392:	total: 59.6s	remaining: 1m 32s
# 393:	total: 59.8s	remaining: 1m 31s
# 394:	total: 59.9s	remaining: 1m 31s
# 395:	total: 1m	remaining: 1m 31s
# 396:	total: 1m	remaining: 1m 31s
# 397:	total: 1m	remaining: 1m 31s
# 398:	total: 1m	remaining: 1m 31s
# 399:	total: 1m	remaining: 1m 31s
# 400:	total: 1m	remaining: 1m 30s
# 401:	total: 1m	remaining: 1m 30s
# 402:	total: 1m 1s	remaining: 1m 30s
# 403:	total: 1m 1s	remaining: 1m 30s
# 404:	total: 1m 1s	remaining: 1m 30s
# 405:	total: 1m 1s	remaining: 1m 29s
# 406:	total: 1m 1s	remaining: 1m 29s
# 407:	total: 1m 1s	remaining: 1m 29s
# 408:	total: 1m 1s	remaining: 1m 29s
# 409:	total: 1m 2s	remaining: 1m 29s
# 410:	total: 1m 2s	remaining: 1m 29s
# 411:	total: 1m 2s	remaining: 1m 29s
# 412:	total: 1m 2s	remaining: 1m 28s
# 413:	total: 1m 2s	remaining: 1m 28s
# 414:	total: 1m 2s	remaining: 1m 28s
# 415:	total: 1m 2s	remaining: 1m 28s
# 416:	total: 1m 3s	remaining: 1m 28s
# 417:	total: 1m 3s	remaining: 1m 28s
# 418:	total: 1m 3s	remaining: 1m 27s
# 419:	total: 1m 3s	remaining: 1m 27s
# 420:	total: 1m 3s	remaining: 1m 27s
# 421:	total: 1m 3s	remaining: 1m 27s
# 422:	total: 1m 3s	remaining: 1m 27s
# 423:	total: 1m 4s	remaining: 1m 27s
# 424:	total: 1m 4s	remaining: 1m 26s
# 425:	total: 1m 4s	remaining: 1m 26s
# 426:	total: 1m 4s	remaining: 1m 26s
# 427:	total: 1m 4s	remaining: 1m 26s
# 428:	total: 1m 4s	remaining: 1m 26s
# 429:	total: 1m 4s	remaining: 1m 26s
# 430:	total: 1m 5s	remaining: 1m 25s
# 431:	total: 1m 5s	remaining: 1m 25s
# 432:	total: 1m 5s	remaining: 1m 25s
# 433:	total: 1m 5s	remaining: 1m 25s
# 434:	total: 1m 5s	remaining: 1m 25s
# 435:	total: 1m 5s	remaining: 1m 25s
# 436:	total: 1m 5s	remaining: 1m 24s
# 437:	total: 1m 6s	remaining: 1m 24s
# 438:	total: 1m 6s	remaining: 1m 24s
# 439:	total: 1m 6s	remaining: 1m 24s
# 440:	total: 1m 6s	remaining: 1m 24s
# 441:	total: 1m 6s	remaining: 1m 24s
# 442:	total: 1m 6s	remaining: 1m 24s
# 443:	total: 1m 6s	remaining: 1m 23s
# 444:	total: 1m 7s	remaining: 1m 23s
# 445:	total: 1m 7s	remaining: 1m 23s
# 446:	total: 1m 7s	remaining: 1m 23s
# 447:	total: 1m 7s	remaining: 1m 23s
# 448:	total: 1m 7s	remaining: 1m 23s
# 449:	total: 1m 7s	remaining: 1m 22s
# 450:	total: 1m 8s	remaining: 1m 22s
# 451:	total: 1m 8s	remaining: 1m 22s
# 452:	total: 1m 8s	remaining: 1m 22s
# 453:	total: 1m 8s	remaining: 1m 22s
# 454:	total: 1m 8s	remaining: 1m 22s
# 455:	total: 1m 8s	remaining: 1m 22s
# 456:	total: 1m 8s	remaining: 1m 21s
# 457:	total: 1m 9s	remaining: 1m 21s
# 458:	total: 1m 9s	remaining: 1m 21s
# 459:	total: 1m 9s	remaining: 1m 21s
# 460:	total: 1m 9s	remaining: 1m 21s
# 461:	total: 1m 9s	remaining: 1m 20s
# 462:	total: 1m 9s	remaining: 1m 20s
# 463:	total: 1m 9s	remaining: 1m 20s
# 464:	total: 1m 10s	remaining: 1m 20s
# 465:	total: 1m 10s	remaining: 1m 20s
# 466:	total: 1m 10s	remaining: 1m 20s
# 467:	total: 1m 10s	remaining: 1m 20s
# 468:	total: 1m 10s	remaining: 1m 19s
# 469:	total: 1m 10s	remaining: 1m 19s
# 470:	total: 1m 10s	remaining: 1m 19s
# 471:	total: 1m 11s	remaining: 1m 19s
# 472:	total: 1m 11s	remaining: 1m 19s
# 473:	total: 1m 11s	remaining: 1m 19s
# 474:	total: 1m 11s	remaining: 1m 18s
# 475:	total: 1m 11s	remaining: 1m 18s
# 476:	total: 1m 11s	remaining: 1m 18s
# 477:	total: 1m 11s	remaining: 1m 18s
# 478:	total: 1m 12s	remaining: 1m 18s
# 479:	total: 1m 12s	remaining: 1m 18s
# 480:	total: 1m 12s	remaining: 1m 18s
# 481:	total: 1m 12s	remaining: 1m 17s
# 482:	total: 1m 12s	remaining: 1m 17s
# 483:	total: 1m 12s	remaining: 1m 17s
# 484:	total: 1m 12s	remaining: 1m 17s
# 485:	total: 1m 12s	remaining: 1m 17s
# 486:	total: 1m 13s	remaining: 1m 17s
# 487:	total: 1m 13s	remaining: 1m 16s
# 488:	total: 1m 13s	remaining: 1m 16s
# 489:	total: 1m 13s	remaining: 1m 16s
# 490:	total: 1m 13s	remaining: 1m 16s
# 491:	total: 1m 13s	remaining: 1m 16s
# 492:	total: 1m 13s	remaining: 1m 16s
# 493:	total: 1m 14s	remaining: 1m 15s
# 494:	total: 1m 14s	remaining: 1m 15s
# 495:	total: 1m 14s	remaining: 1m 15s
# 496:	total: 1m 14s	remaining: 1m 15s
# 497:	total: 1m 14s	remaining: 1m 15s
# 498:	total: 1m 14s	remaining: 1m 15s
# 499:	total: 1m 14s	remaining: 1m 14s
# 500:	total: 1m 15s	remaining: 1m 14s
# 501:	total: 1m 15s	remaining: 1m 14s
# 502:	total: 1m 15s	remaining: 1m 14s
# 503:	total: 1m 15s	remaining: 1m 14s
# 504:	total: 1m 15s	remaining: 1m 14s
# 505:	total: 1m 15s	remaining: 1m 13s
# 506:	total: 1m 15s	remaining: 1m 13s
# 507:	total: 1m 16s	remaining: 1m 13s
# 508:	total: 1m 16s	remaining: 1m 13s
# 509:	total: 1m 16s	remaining: 1m 13s
# 510:	total: 1m 16s	remaining: 1m 13s
# 511:	total: 1m 16s	remaining: 1m 13s
# 512:	total: 1m 16s	remaining: 1m 12s
# 513:	total: 1m 16s	remaining: 1m 12s
# 514:	total: 1m 16s	remaining: 1m 12s
# 515:	total: 1m 17s	remaining: 1m 12s
# 516:	total: 1m 17s	remaining: 1m 12s
# 517:	total: 1m 17s	remaining: 1m 11s
# 518:	total: 1m 17s	remaining: 1m 11s
# 519:	total: 1m 17s	remaining: 1m 11s
# 520:	total: 1m 17s	remaining: 1m 11s
# 521:	total: 1m 17s	remaining: 1m 11s
# 522:	total: 1m 18s	remaining: 1m 11s
# 523:	total: 1m 18s	remaining: 1m 11s
# 524:	total: 1m 18s	remaining: 1m 10s
# 525:	total: 1m 18s	remaining: 1m 10s
# 526:	total: 1m 18s	remaining: 1m 10s
# 527:	total: 1m 18s	remaining: 1m 10s
# 528:	total: 1m 18s	remaining: 1m 10s
# 529:	total: 1m 19s	remaining: 1m 10s
# 530:	total: 1m 19s	remaining: 1m 9s
# 531:	total: 1m 19s	remaining: 1m 9s
# 532:	total: 1m 19s	remaining: 1m 9s
# 533:	total: 1m 19s	remaining: 1m 9s
# 534:	total: 1m 19s	remaining: 1m 9s
# 535:	total: 1m 19s	remaining: 1m 9s
# 536:	total: 1m 20s	remaining: 1m 9s
# 537:	total: 1m 20s	remaining: 1m 9s
# 538:	total: 1m 20s	remaining: 1m 9s
# 539:	total: 1m 20s	remaining: 1m 8s
# 540:	total: 1m 21s	remaining: 1m 8s
# 541:	total: 1m 21s	remaining: 1m 8s
# 542:	total: 1m 21s	remaining: 1m 8s
# 543:	total: 1m 21s	remaining: 1m 8s
# 544:	total: 1m 22s	remaining: 1m 8s
# 545:	total: 1m 22s	remaining: 1m 8s
# 546:	total: 1m 22s	remaining: 1m 8s
# 547:	total: 1m 23s	remaining: 1m 8s
# 548:	total: 1m 23s	remaining: 1m 8s
# 549:	total: 1m 23s	remaining: 1m 8s
# 550:	total: 1m 23s	remaining: 1m 8s
# 551:	total: 1m 23s	remaining: 1m 8s
# 552:	total: 1m 24s	remaining: 1m 7s
# 553:	total: 1m 24s	remaining: 1m 7s
# 554:	total: 1m 24s	remaining: 1m 7s
# 555:	total: 1m 24s	remaining: 1m 7s
# 556:	total: 1m 24s	remaining: 1m 7s
# 557:	total: 1m 25s	remaining: 1m 7s
# 558:	total: 1m 25s	remaining: 1m 7s
# 559:	total: 1m 25s	remaining: 1m 7s
# 560:	total: 1m 25s	remaining: 1m 6s
# 561:	total: 1m 25s	remaining: 1m 6s
# 562:	total: 1m 26s	remaining: 1m 6s
# 563:	total: 1m 26s	remaining: 1m 6s
# 564:	total: 1m 26s	remaining: 1m 6s
# 565:	total: 1m 26s	remaining: 1m 6s
# 566:	total: 1m 26s	remaining: 1m 6s
# 567:	total: 1m 26s	remaining: 1m 6s
# 568:	total: 1m 26s	remaining: 1m 5s
# 569:	total: 1m 27s	remaining: 1m 5s
# 570:	total: 1m 27s	remaining: 1m 5s
# 571:	total: 1m 27s	remaining: 1m 5s
# 572:	total: 1m 27s	remaining: 1m 5s
# 573:	total: 1m 27s	remaining: 1m 5s
# 574:	total: 1m 27s	remaining: 1m 4s
# 575:	total: 1m 27s	remaining: 1m 4s
# 576:	total: 1m 28s	remaining: 1m 4s
# 577:	total: 1m 28s	remaining: 1m 4s
# 578:	total: 1m 28s	remaining: 1m 4s
# 579:	total: 1m 28s	remaining: 1m 4s
# 580:	total: 1m 28s	remaining: 1m 4s
# 581:	total: 1m 28s	remaining: 1m 3s
# 582:	total: 1m 29s	remaining: 1m 3s
# 583:	total: 1m 29s	remaining: 1m 3s
# 584:	total: 1m 29s	remaining: 1m 3s
# 585:	total: 1m 29s	remaining: 1m 3s
# 586:	total: 1m 29s	remaining: 1m 3s
# 587:	total: 1m 29s	remaining: 1m 2s
# 588:	total: 1m 29s	remaining: 1m 2s
# 589:	total: 1m 30s	remaining: 1m 2s
# 590:	total: 1m 30s	remaining: 1m 2s
# 591:	total: 1m 30s	remaining: 1m 2s
# 592:	total: 1m 30s	remaining: 1m 2s
# 593:	total: 1m 30s	remaining: 1m 1s
# 594:	total: 1m 30s	remaining: 1m 1s
# 595:	total: 1m 30s	remaining: 1m 1s
# 596:	total: 1m 31s	remaining: 1m 1s
# 597:	total: 1m 31s	remaining: 1m 1s
# 598:	total: 1m 31s	remaining: 1m 1s
# 599:	total: 1m 31s	remaining: 1m
# 600:	total: 1m 31s	remaining: 1m
# 601:	total: 1m 31s	remaining: 1m
# 602:	total: 1m 31s	remaining: 1m
# 603:	total: 1m 32s	remaining: 1m
# 604:	total: 1m 32s	remaining: 1m
# 605:	total: 1m 32s	remaining: 1m
# 606:	total: 1m 32s	remaining: 59.9s
# 607:	total: 1m 32s	remaining: 59.7s
# 608:	total: 1m 32s	remaining: 59.5s
# 609:	total: 1m 32s	remaining: 59.4s
# 610:	total: 1m 33s	remaining: 59.3s
# 611:	total: 1m 33s	remaining: 59.1s
# 612:	total: 1m 33s	remaining: 58.9s
# 613:	total: 1m 33s	remaining: 58.8s
# 614:	total: 1m 33s	remaining: 58.7s
# 615:	total: 1m 33s	remaining: 58.5s
# 616:	total: 1m 34s	remaining: 58.4s
# 617:	total: 1m 34s	remaining: 58.3s
# 618:	total: 1m 34s	remaining: 58.1s
# 619:	total: 1m 34s	remaining: 57.9s
# 620:	total: 1m 34s	remaining: 57.8s
# 621:	total: 1m 34s	remaining: 57.6s
# 622:	total: 1m 34s	remaining: 57.5s
# 623:	total: 1m 35s	remaining: 57.3s
# 624:	total: 1m 35s	remaining: 57.2s
# 625:	total: 1m 35s	remaining: 57s
# 626:	total: 1m 35s	remaining: 56.9s
# 627:	total: 1m 35s	remaining: 56.7s
# 628:	total: 1m 35s	remaining: 56.5s
# 629:	total: 1m 35s	remaining: 56.4s
# 630:	total: 1m 36s	remaining: 56.2s
# 631:	total: 1m 36s	remaining: 56.1s
# 632:	total: 1m 36s	remaining: 55.9s
# 633:	total: 1m 36s	remaining: 55.8s
# 634:	total: 1m 36s	remaining: 55.6s
# 635:	total: 1m 36s	remaining: 55.4s
# 636:	total: 1m 36s	remaining: 55.3s
# 637:	total: 1m 37s	remaining: 55.1s
# 638:	total: 1m 37s	remaining: 54.9s
# 639:	total: 1m 37s	remaining: 54.8s
# 640:	total: 1m 37s	remaining: 54.7s
# 641:	total: 1m 37s	remaining: 54.5s
# 642:	total: 1m 37s	remaining: 54.3s
# 643:	total: 1m 37s	remaining: 54.2s
# 644:	total: 1m 38s	remaining: 54s
# 645:	total: 1m 38s	remaining: 53.8s
# 646:	total: 1m 38s	remaining: 53.7s
# 647:	total: 1m 38s	remaining: 53.5s
# 648:	total: 1m 38s	remaining: 53.4s
# 649:	total: 1m 38s	remaining: 53.2s
# 650:	total: 1m 38s	remaining: 53.1s
# 651:	total: 1m 39s	remaining: 52.9s
# 652:	total: 1m 39s	remaining: 52.7s
# 653:	total: 1m 39s	remaining: 52.6s
# 654:	total: 1m 39s	remaining: 52.5s
# 655:	total: 1m 39s	remaining: 52.3s
# 656:	total: 1m 39s	remaining: 52.2s
# 657:	total: 1m 40s	remaining: 52s
# 658:	total: 1m 40s	remaining: 51.8s
# 659:	total: 1m 40s	remaining: 51.7s
# 660:	total: 1m 40s	remaining: 51.5s
# 661:	total: 1m 40s	remaining: 51.4s
# 662:	total: 1m 40s	remaining: 51.2s
# 663:	total: 1m 40s	remaining: 51.1s
# 664:	total: 1m 41s	remaining: 50.9s
# 665:	total: 1m 41s	remaining: 50.7s
# 666:	total: 1m 41s	remaining: 50.6s
# 667:	total: 1m 41s	remaining: 50.4s
# 668:	total: 1m 41s	remaining: 50.3s
# 669:	total: 1m 41s	remaining: 50.1s
# 670:	total: 1m 41s	remaining: 50s
# 671:	total: 1m 42s	remaining: 49.8s
# 672:	total: 1m 42s	remaining: 49.7s
# 673:	total: 1m 42s	remaining: 49.5s
# 674:	total: 1m 42s	remaining: 49.3s
# 675:	total: 1m 42s	remaining: 49.2s
# 676:	total: 1m 42s	remaining: 49s
# 677:	total: 1m 42s	remaining: 48.9s
# 678:	total: 1m 43s	remaining: 48.7s
# 679:	total: 1m 43s	remaining: 48.6s
# 680:	total: 1m 43s	remaining: 48.4s
# 681:	total: 1m 43s	remaining: 48.2s
# 682:	total: 1m 43s	remaining: 48.1s
# 683:	total: 1m 43s	remaining: 47.9s
# 684:	total: 1m 43s	remaining: 47.8s
# 685:	total: 1m 43s	remaining: 47.6s
# 686:	total: 1m 44s	remaining: 47.4s
# 687:	total: 1m 44s	remaining: 47.3s
# 688:	total: 1m 44s	remaining: 47.2s
# 689:	total: 1m 44s	remaining: 47s
# 690:	total: 1m 44s	remaining: 46.9s
# 691:	total: 1m 44s	remaining: 46.7s
# 692:	total: 1m 45s	remaining: 46.5s
# 693:	total: 1m 45s	remaining: 46.4s
# 694:	total: 1m 45s	remaining: 46.2s
# 695:	total: 1m 45s	remaining: 46.1s
# 696:	total: 1m 45s	remaining: 45.9s
# 697:	total: 1m 45s	remaining: 45.8s
# 698:	total: 1m 45s	remaining: 45.6s
# 699:	total: 1m 46s	remaining: 45.4s
# 700:	total: 1m 46s	remaining: 45.3s
# 701:	total: 1m 46s	remaining: 45.1s
# 702:	total: 1m 46s	remaining: 45s
# 703:	total: 1m 46s	remaining: 44.8s
# 704:	total: 1m 46s	remaining: 44.7s
# 705:	total: 1m 46s	remaining: 44.5s
# 706:	total: 1m 47s	remaining: 44.4s
# 707:	total: 1m 47s	remaining: 44.2s
# 708:	total: 1m 47s	remaining: 44.1s
# 709:	total: 1m 47s	remaining: 43.9s
# 710:	total: 1m 47s	remaining: 43.8s
# 711:	total: 1m 47s	remaining: 43.6s
# 712:	total: 1m 48s	remaining: 43.5s
# 713:	total: 1m 48s	remaining: 43.3s
# 714:	total: 1m 48s	remaining: 43.2s
# 715:	total: 1m 48s	remaining: 43s
# 716:	total: 1m 48s	remaining: 42.8s
# 717:	total: 1m 48s	remaining: 42.7s
# 718:	total: 1m 48s	remaining: 42.6s
# 719:	total: 1m 49s	remaining: 42.4s
# 720:	total: 1m 49s	remaining: 42.3s
# 721:	total: 1m 49s	remaining: 42.1s
# 722:	total: 1m 49s	remaining: 41.9s
# 723:	total: 1m 49s	remaining: 41.8s
# 724:	total: 1m 49s	remaining: 41.6s
# 725:	total: 1m 49s	remaining: 41.5s
# 726:	total: 1m 50s	remaining: 41.3s
# 727:	total: 1m 50s	remaining: 41.2s
# 728:	total: 1m 50s	remaining: 41s
# 729:	total: 1m 50s	remaining: 40.9s
# 730:	total: 1m 50s	remaining: 40.7s
# 731:	total: 1m 50s	remaining: 40.5s
# 732:	total: 1m 50s	remaining: 40.4s
# 733:	total: 1m 50s	remaining: 40.2s
# 734:	total: 1m 51s	remaining: 40s
# 735:	total: 1m 51s	remaining: 39.9s
# 736:	total: 1m 51s	remaining: 39.7s
# 737:	total: 1m 51s	remaining: 39.6s
# 738:	total: 1m 51s	remaining: 39.4s
# 739:	total: 1m 51s	remaining: 39.3s
# 740:	total: 1m 51s	remaining: 39.1s
# 741:	total: 1m 52s	remaining: 38.9s
# 742:	total: 1m 52s	remaining: 38.8s
# 743:	total: 1m 52s	remaining: 38.7s
# 744:	total: 1m 52s	remaining: 38.5s
# 745:	total: 1m 52s	remaining: 38.3s
# 746:	total: 1m 52s	remaining: 38.2s
# 747:	total: 1m 52s	remaining: 38s
# 748:	total: 1m 53s	remaining: 37.9s
# 749:	total: 1m 53s	remaining: 37.7s
# 750:	total: 1m 53s	remaining: 37.6s
# 751:	total: 1m 53s	remaining: 37.4s
# 752:	total: 1m 53s	remaining: 37.3s
# 753:	total: 1m 53s	remaining: 37.1s
# 754:	total: 1m 53s	remaining: 37s
# 755:	total: 1m 54s	remaining: 36.8s
# 756:	total: 1m 54s	remaining: 36.6s
# 757:	total: 1m 54s	remaining: 36.5s
# 758:	total: 1m 54s	remaining: 36.3s
# 759:	total: 1m 54s	remaining: 36.2s
# 760:	total: 1m 54s	remaining: 36s
# 761:	total: 1m 54s	remaining: 35.9s
# 762:	total: 1m 55s	remaining: 35.7s
# 763:	total: 1m 55s	remaining: 35.6s
# 764:	total: 1m 55s	remaining: 35.4s
# 765:	total: 1m 55s	remaining: 35.3s
# 766:	total: 1m 55s	remaining: 35.1s
# 767:	total: 1m 55s	remaining: 35s
# 768:	total: 1m 55s	remaining: 34.8s
# 769:	total: 1m 56s	remaining: 34.7s
# 770:	total: 1m 56s	remaining: 34.5s
# 771:	total: 1m 56s	remaining: 34.3s
# 772:	total: 1m 56s	remaining: 34.2s
# 773:	total: 1m 56s	remaining: 34s
# 774:	total: 1m 56s	remaining: 33.9s
# 775:	total: 1m 56s	remaining: 33.7s
# 776:	total: 1m 57s	remaining: 33.6s
# 777:	total: 1m 57s	remaining: 33.4s
# 778:	total: 1m 57s	remaining: 33.3s
# 779:	total: 1m 57s	remaining: 33.1s
# 780:	total: 1m 57s	remaining: 33s
# 781:	total: 1m 57s	remaining: 32.8s
# 782:	total: 1m 57s	remaining: 32.7s
# 783:	total: 1m 57s	remaining: 32.5s
# 784:	total: 1m 58s	remaining: 32.4s
# 785:	total: 1m 58s	remaining: 32.2s
# 786:	total: 1m 58s	remaining: 32.1s
# 787:	total: 1m 58s	remaining: 31.9s
# 788:	total: 1m 58s	remaining: 31.7s
# 789:	total: 1m 58s	remaining: 31.6s
# 790:	total: 1m 58s	remaining: 31.4s
# 791:	total: 1m 59s	remaining: 31.3s
# 792:	total: 1m 59s	remaining: 31.1s
# 793:	total: 1m 59s	remaining: 31s
# 794:	total: 1m 59s	remaining: 30.8s
# 795:	total: 1m 59s	remaining: 30.7s
# 796:	total: 1m 59s	remaining: 30.5s
# 797:	total: 1m 59s	remaining: 30.4s
# 798:	total: 2m	remaining: 30.2s
# 799:	total: 2m	remaining: 30s
# 800:	total: 2m	remaining: 29.9s
# 801:	total: 2m	remaining: 29.8s
# 802:	total: 2m	remaining: 29.6s
# 803:	total: 2m	remaining: 29.4s
# 804:	total: 2m	remaining: 29.3s
# 805:	total: 2m 1s	remaining: 29.1s
# 806:	total: 2m 1s	remaining: 29s
# 807:	total: 2m 1s	remaining: 28.8s
# 808:	total: 2m 1s	remaining: 28.7s
# 809:	total: 2m 1s	remaining: 28.5s
# 810:	total: 2m 1s	remaining: 28.4s
# 811:	total: 2m 1s	remaining: 28.2s
# 812:	total: 2m 2s	remaining: 28.1s
# 813:	total: 2m 2s	remaining: 28s
# 814:	total: 2m 2s	remaining: 27.8s
# 815:	total: 2m 2s	remaining: 27.7s
# 816:	total: 2m 2s	remaining: 27.5s
# 817:	total: 2m 3s	remaining: 27.4s
# 818:	total: 2m 3s	remaining: 27.3s
# 819:	total: 2m 3s	remaining: 27.1s
# 820:	total: 2m 3s	remaining: 27s
# 821:	total: 2m 3s	remaining: 26.9s
# 822:	total: 2m 4s	remaining: 26.7s
# 823:	total: 2m 4s	remaining: 26.6s
# 824:	total: 2m 4s	remaining: 26.4s
# 825:	total: 2m 4s	remaining: 26.2s
# 826:	total: 2m 4s	remaining: 26.1s
# 827:	total: 2m 4s	remaining: 25.9s
# 828:	total: 2m 5s	remaining: 25.8s
# 829:	total: 2m 5s	remaining: 25.6s
# 830:	total: 2m 5s	remaining: 25.5s
# 831:	total: 2m 5s	remaining: 25.3s
# 832:	total: 2m 5s	remaining: 25.2s
# 833:	total: 2m 5s	remaining: 25s
# 834:	total: 2m 5s	remaining: 24.9s
# 835:	total: 2m 6s	remaining: 24.7s
# 836:	total: 2m 6s	remaining: 24.6s
# 837:	total: 2m 6s	remaining: 24.4s
# 838:	total: 2m 6s	remaining: 24.3s
# 839:	total: 2m 6s	remaining: 24.1s
# 840:	total: 2m 6s	remaining: 24s
# 841:	total: 2m 6s	remaining: 23.8s
# 842:	total: 2m 6s	remaining: 23.6s
# 843:	total: 2m 7s	remaining: 23.5s
# 844:	total: 2m 7s	remaining: 23.4s
# 845:	total: 2m 7s	remaining: 23.2s
# 846:	total: 2m 7s	remaining: 23.1s
# 847:	total: 2m 7s	remaining: 22.9s
# 848:	total: 2m 7s	remaining: 22.7s
# 849:	total: 2m 7s	remaining: 22.6s
# 850:	total: 2m 8s	remaining: 22.4s
# 851:	total: 2m 8s	remaining: 22.3s
# 852:	total: 2m 8s	remaining: 22.1s
# 853:	total: 2m 8s	remaining: 22s
# 854:	total: 2m 8s	remaining: 21.8s
# 855:	total: 2m 8s	remaining: 21.7s
# 856:	total: 2m 8s	remaining: 21.5s
# 857:	total: 2m 9s	remaining: 21.4s
# 858:	total: 2m 9s	remaining: 21.2s
# 859:	total: 2m 9s	remaining: 21.1s
# 860:	total: 2m 9s	remaining: 20.9s
# 861:	total: 2m 9s	remaining: 20.8s
# 862:	total: 2m 9s	remaining: 20.6s
# 863:	total: 2m 9s	remaining: 20.5s
# 864:	total: 2m 10s	remaining: 20.3s
# 865:	total: 2m 10s	remaining: 20.2s
# 866:	total: 2m 10s	remaining: 20s
# 867:	total: 2m 10s	remaining: 19.8s
# 868:	total: 2m 10s	remaining: 19.7s
# 869:	total: 2m 10s	remaining: 19.6s
# 870:	total: 2m 10s	remaining: 19.4s
# 871:	total: 2m 11s	remaining: 19.2s
# 872:	total: 2m 11s	remaining: 19.1s
# 873:	total: 2m 11s	remaining: 18.9s
# 874:	total: 2m 11s	remaining: 18.8s
# 875:	total: 2m 11s	remaining: 18.6s
# 876:	total: 2m 11s	remaining: 18.5s
# 877:	total: 2m 11s	remaining: 18.3s
# 878:	total: 2m 12s	remaining: 18.2s
# 879:	total: 2m 12s	remaining: 18s
# 880:	total: 2m 12s	remaining: 17.9s
# 881:	total: 2m 12s	remaining: 17.7s
# 882:	total: 2m 12s	remaining: 17.6s
# 883:	total: 2m 12s	remaining: 17.4s
# 884:	total: 2m 12s	remaining: 17.3s
# 885:	total: 2m 13s	remaining: 17.1s
# 886:	total: 2m 13s	remaining: 17s
# 887:	total: 2m 13s	remaining: 16.8s
# 888:	total: 2m 13s	remaining: 16.7s
# 889:	total: 2m 13s	remaining: 16.5s
# 890:	total: 2m 13s	remaining: 16.4s
# 891:	total: 2m 13s	remaining: 16.2s
# 892:	total: 2m 14s	remaining: 16.1s
# 893:	total: 2m 14s	remaining: 15.9s
# 894:	total: 2m 14s	remaining: 15.8s
# 895:	total: 2m 14s	remaining: 15.6s
# 896:	total: 2m 14s	remaining: 15.5s
# 897:	total: 2m 14s	remaining: 15.3s
# 898:	total: 2m 14s	remaining: 15.2s
# 899:	total: 2m 15s	remaining: 15s
# 900:	total: 2m 15s	remaining: 14.8s
# 901:	total: 2m 15s	remaining: 14.7s
# 902:	total: 2m 15s	remaining: 14.6s
# 903:	total: 2m 15s	remaining: 14.4s
# 904:	total: 2m 15s	remaining: 14.3s
# 905:	total: 2m 15s	remaining: 14.1s
# 906:	total: 2m 16s	remaining: 13.9s
# 907:	total: 2m 16s	remaining: 13.8s
# 908:	total: 2m 16s	remaining: 13.6s
# 909:	total: 2m 16s	remaining: 13.5s
# 910:	total: 2m 16s	remaining: 13.4s
# 911:	total: 2m 16s	remaining: 13.2s
# 912:	total: 2m 16s	remaining: 13s
# 913:	total: 2m 17s	remaining: 12.9s
# 914:	total: 2m 17s	remaining: 12.7s
# 915:	total: 2m 17s	remaining: 12.6s
# 916:	total: 2m 17s	remaining: 12.4s
# 917:	total: 2m 17s	remaining: 12.3s
# 918:	total: 2m 17s	remaining: 12.1s
# 919:	total: 2m 17s	remaining: 12s
# 920:	total: 2m 18s	remaining: 11.8s
# 921:	total: 2m 18s	remaining: 11.7s
# 922:	total: 2m 18s	remaining: 11.5s
# 923:	total: 2m 18s	remaining: 11.4s
# 924:	total: 2m 18s	remaining: 11.2s
# 925:	total: 2m 18s	remaining: 11.1s
# 926:	total: 2m 18s	remaining: 10.9s
# 927:	total: 2m 19s	remaining: 10.8s
# 928:	total: 2m 19s	remaining: 10.6s
# 929:	total: 2m 19s	remaining: 10.5s
# 930:	total: 2m 19s	remaining: 10.3s
# 931:	total: 2m 19s	remaining: 10.2s
# 932:	total: 2m 20s	remaining: 10.1s
# 933:	total: 2m 20s	remaining: 9.91s
# 934:	total: 2m 20s	remaining: 9.76s
# 935:	total: 2m 20s	remaining: 9.62s
# 936:	total: 2m 20s	remaining: 9.47s
# 937:	total: 2m 21s	remaining: 9.33s
# 938:	total: 2m 21s	remaining: 9.19s
# 939:	total: 2m 21s	remaining: 9.04s
# 940:	total: 2m 21s	remaining: 8.9s
# 941:	total: 2m 22s	remaining: 8.75s
# 942:	total: 2m 22s	remaining: 8.61s
# 943:	total: 2m 22s	remaining: 8.46s
# 944:	total: 2m 22s	remaining: 8.31s
# 945:	total: 2m 23s	remaining: 8.16s
# 946:	total: 2m 23s	remaining: 8.02s
# 947:	total: 2m 23s	remaining: 7.86s
# 948:	total: 2m 23s	remaining: 7.71s
# 949:	total: 2m 23s	remaining: 7.56s
# 950:	total: 2m 23s	remaining: 7.41s
# 951:	total: 2m 23s	remaining: 7.26s
# 952:	total: 2m 24s	remaining: 7.11s
# 953:	total: 2m 24s	remaining: 6.96s
# 954:	total: 2m 24s	remaining: 6.8s
# 955:	total: 2m 24s	remaining: 6.65s
# 956:	total: 2m 24s	remaining: 6.5s
# 957:	total: 2m 24s	remaining: 6.35s
# 958:	total: 2m 24s	remaining: 6.2s
# 959:	total: 2m 25s	remaining: 6.05s
# 960:	total: 2m 25s	remaining: 5.89s
# 961:	total: 2m 25s	remaining: 5.74s
# 962:	total: 2m 25s	remaining: 5.59s
# 963:	total: 2m 25s	remaining: 5.44s
# 964:	total: 2m 25s	remaining: 5.29s
# 965:	total: 2m 25s	remaining: 5.14s
# 966:	total: 2m 26s	remaining: 4.99s
# 967:	total: 2m 26s	remaining: 4.83s
# 968:	total: 2m 26s	remaining: 4.68s
# 969:	total: 2m 26s	remaining: 4.53s
# 970:	total: 2m 26s	remaining: 4.38s
# 971:	total: 2m 26s	remaining: 4.23s
# 972:	total: 2m 26s	remaining: 4.08s
# 973:	total: 2m 27s	remaining: 3.93s
# 974:	total: 2m 27s	remaining: 3.78s
# 975:	total: 2m 27s	remaining: 3.62s
# 976:	total: 2m 27s	remaining: 3.47s
# 977:	total: 2m 27s	remaining: 3.32s
# 978:	total: 2m 27s	remaining: 3.17s
# 979:	total: 2m 27s	remaining: 3.02s
# 980:	total: 2m 28s	remaining: 2.87s
# 981:	total: 2m 28s	remaining: 2.72s
# 982:	total: 2m 28s	remaining: 2.57s
# 983:	total: 2m 28s	remaining: 2.42s
# 984:	total: 2m 28s	remaining: 2.26s
# 985:	total: 2m 28s	remaining: 2.11s
# 986:	total: 2m 28s	remaining: 1.96s
# 987:	total: 2m 29s	remaining: 1.81s
# 988:	total: 2m 29s	remaining: 1.66s
# 989:	total: 2m 29s	remaining: 1.51s
# 990:	total: 2m 29s	remaining: 1.36s
# 991:	total: 2m 29s	remaining: 1.21s
# 992:	total: 2m 29s	remaining: 1.05s
# 993:	total: 2m 29s	remaining: 905ms
# 994:	total: 2m 30s	remaining: 754ms
# 995:	total: 2m 30s	remaining: 603ms
# 996:	total: 2m 30s	remaining: 452ms
# 997:	total: 2m 30s	remaining: 301ms
# 998:	total: 2m 30s	remaining: 151ms
# 999:	total: 2m 30s	remaining: 0us
# Learning rate set to 0.066122
# 0:	total: 140ms	remaining: 2m 19s
# 1:	total: 312ms	remaining: 2m 35s
# 2:	total: 437ms	remaining: 2m 25s
# 3:	total: 573ms	remaining: 2m 22s
# 4:	total: 788ms	remaining: 2m 36s
# 5:	total: 940ms	remaining: 2m 35s
# 6:	total: 1.09s	remaining: 2m 34s
# 7:	total: 1.21s	remaining: 2m 30s
# 8:	total: 1.36s	remaining: 2m 30s
# 9:	total: 1.49s	remaining: 2m 27s
# 10:	total: 1.63s	remaining: 2m 26s
# 11:	total: 1.81s	remaining: 2m 29s
# 12:	total: 2s	remaining: 2m 31s
# 13:	total: 2.14s	remaining: 2m 30s
# 14:	total: 2.25s	remaining: 2m 28s
# 15:	total: 2.39s	remaining: 2m 27s
# 16:	total: 2.52s	remaining: 2m 25s
# 17:	total: 2.67s	remaining: 2m 25s
# 18:	total: 2.81s	remaining: 2m 25s
# 19:	total: 3s	remaining: 2m 27s
# 20:	total: 3.16s	remaining: 2m 27s
# 21:	total: 3.31s	remaining: 2m 26s
# 22:	total: 3.43s	remaining: 2m 25s
# 23:	total: 3.57s	remaining: 2m 25s
# 24:	total: 3.69s	remaining: 2m 24s
# 25:	total: 3.84s	remaining: 2m 23s
# 26:	total: 3.96s	remaining: 2m 22s
# 27:	total: 4.19s	remaining: 2m 25s
# 28:	total: 4.31s	remaining: 2m 24s
# 29:	total: 4.44s	remaining: 2m 23s
# 30:	total: 4.57s	remaining: 2m 22s
# 31:	total: 4.71s	remaining: 2m 22s
# 32:	total: 4.84s	remaining: 2m 21s
# 33:	total: 4.99s	remaining: 2m 21s
# 34:	total: 5.11s	remaining: 2m 20s
# 35:	total: 5.31s	remaining: 2m 22s
# 36:	total: 5.44s	remaining: 2m 21s
# 37:	total: 5.58s	remaining: 2m 21s
# 38:	total: 5.72s	remaining: 2m 21s
# 39:	total: 5.86s	remaining: 2m 20s
# 40:	total: 5.98s	remaining: 2m 19s
# 41:	total: 6.13s	remaining: 2m 19s
# 42:	total: 6.26s	remaining: 2m 19s
# 43:	total: 6.44s	remaining: 2m 19s
# 44:	total: 6.59s	remaining: 2m 19s
# 45:	total: 6.75s	remaining: 2m 20s
# 46:	total: 6.88s	remaining: 2m 19s
# 47:	total: 7.03s	remaining: 2m 19s
# 48:	total: 7.16s	remaining: 2m 18s
# 49:	total: 7.3s	remaining: 2m 18s
# 50:	total: 7.43s	remaining: 2m 18s
# 51:	total: 7.66s	remaining: 2m 19s
# 52:	total: 7.79s	remaining: 2m 19s
# 53:	total: 7.95s	remaining: 2m 19s
# 54:	total: 8.07s	remaining: 2m 18s
# 55:	total: 8.22s	remaining: 2m 18s
# 56:	total: 8.37s	remaining: 2m 18s
# 57:	total: 8.6s	remaining: 2m 19s
# 58:	total: 8.89s	remaining: 2m 21s
# 59:	total: 9.09s	remaining: 2m 22s
# 60:	total: 9.33s	remaining: 2m 23s
# 61:	total: 9.52s	remaining: 2m 24s
# 62:	total: 9.7s	remaining: 2m 24s
# 63:	total: 9.95s	remaining: 2m 25s
# 64:	total: 10.1s	remaining: 2m 25s
# 65:	total: 10.4s	remaining: 2m 26s
# 66:	total: 10.6s	remaining: 2m 27s
# 67:	total: 10.8s	remaining: 2m 27s
# 68:	total: 11s	remaining: 2m 28s
# 69:	total: 11.2s	remaining: 2m 29s
# 70:	total: 11.4s	remaining: 2m 28s
# 71:	total: 11.5s	remaining: 2m 28s
# 72:	total: 11.6s	remaining: 2m 27s
# 73:	total: 11.8s	remaining: 2m 27s
# 74:	total: 11.9s	remaining: 2m 26s
# 75:	total: 12s	remaining: 2m 26s
# 76:	total: 12.2s	remaining: 2m 25s
# 77:	total: 12.4s	remaining: 2m 26s
# 78:	total: 12.5s	remaining: 2m 25s
# 79:	total: 12.7s	remaining: 2m 25s
# 80:	total: 12.8s	remaining: 2m 25s
# 81:	total: 13s	remaining: 2m 25s
# 82:	total: 13.1s	remaining: 2m 24s
# 83:	total: 13.3s	remaining: 2m 24s
# 84:	total: 13.4s	remaining: 2m 24s
# 85:	total: 13.6s	remaining: 2m 24s
# 86:	total: 13.7s	remaining: 2m 24s
# 87:	total: 13.9s	remaining: 2m 23s
# 88:	total: 14s	remaining: 2m 23s
# 89:	total: 14.2s	remaining: 2m 23s
# 90:	total: 14.3s	remaining: 2m 22s
# 91:	total: 14.4s	remaining: 2m 22s
# 92:	total: 14.6s	remaining: 2m 22s
# 93:	total: 14.8s	remaining: 2m 22s
# 94:	total: 14.9s	remaining: 2m 22s
# 95:	total: 15s	remaining: 2m 21s
# 96:	total: 15.2s	remaining: 2m 21s
# 97:	total: 15.3s	remaining: 2m 20s
# 98:	total: 15.4s	remaining: 2m 20s
# 99:	total: 15.6s	remaining: 2m 20s
# 100:	total: 15.8s	remaining: 2m 20s
# 101:	total: 16s	remaining: 2m 20s
# 102:	total: 16.1s	remaining: 2m 20s
# 103:	total: 16.2s	remaining: 2m 19s
# 104:	total: 16.4s	remaining: 2m 19s
# 105:	total: 16.5s	remaining: 2m 19s
# 106:	total: 16.6s	remaining: 2m 18s
# 107:	total: 16.8s	remaining: 2m 18s
# 108:	total: 17s	remaining: 2m 18s
# 109:	total: 17.1s	remaining: 2m 18s
# 110:	total: 17.2s	remaining: 2m 18s
# 111:	total: 17.4s	remaining: 2m 17s
# 112:	total: 17.5s	remaining: 2m 17s
# 113:	total: 17.6s	remaining: 2m 17s
# 114:	total: 17.8s	remaining: 2m 16s
# 115:	total: 18s	remaining: 2m 16s
# 116:	total: 18.2s	remaining: 2m 17s
# 117:	total: 18.3s	remaining: 2m 16s
# 118:	total: 18.4s	remaining: 2m 16s
# 119:	total: 18.6s	remaining: 2m 16s
# 120:	total: 18.8s	remaining: 2m 16s
# 121:	total: 18.9s	remaining: 2m 16s
# 122:	total: 19.1s	remaining: 2m 15s
# 123:	total: 19.3s	remaining: 2m 16s
# 124:	total: 19.4s	remaining: 2m 15s
# 125:	total: 19.6s	remaining: 2m 15s
# 126:	total: 19.7s	remaining: 2m 15s
# 127:	total: 19.8s	remaining: 2m 15s
# 128:	total: 20s	remaining: 2m 14s
# 129:	total: 20.1s	remaining: 2m 14s
# 130:	total: 20.2s	remaining: 2m 14s
# 131:	total: 20.5s	remaining: 2m 14s
# 132:	total: 20.6s	remaining: 2m 14s
# 133:	total: 20.7s	remaining: 2m 13s
# 134:	total: 20.9s	remaining: 2m 13s
# 135:	total: 21s	remaining: 2m 13s
# 136:	total: 21.1s	remaining: 2m 13s
# 137:	total: 21.3s	remaining: 2m 12s
# 138:	total: 21.4s	remaining: 2m 12s
# 139:	total: 21.6s	remaining: 2m 12s
# 140:	total: 21.8s	remaining: 2m 12s
# 141:	total: 21.9s	remaining: 2m 12s
# 142:	total: 22s	remaining: 2m 12s
# 143:	total: 22.2s	remaining: 2m 11s
# 144:	total: 22.3s	remaining: 2m 11s
# 145:	total: 22.5s	remaining: 2m 11s
# 146:	total: 22.6s	remaining: 2m 11s
# 147:	total: 22.8s	remaining: 2m 11s
# 148:	total: 23s	remaining: 2m 11s
# 149:	total: 23.1s	remaining: 2m 10s
# 150:	total: 23.2s	remaining: 2m 10s
# 151:	total: 23.3s	remaining: 2m 10s
# 152:	total: 23.5s	remaining: 2m 9s
# 153:	total: 23.6s	remaining: 2m 9s
# 154:	total: 23.7s	remaining: 2m 9s
# 155:	total: 24s	remaining: 2m 9s
# 156:	total: 24.1s	remaining: 2m 9s
# 157:	total: 24.2s	remaining: 2m 9s
# 158:	total: 24.4s	remaining: 2m 8s
# 159:	total: 24.5s	remaining: 2m 8s
# 160:	total: 24.7s	remaining: 2m 8s
# 161:	total: 24.8s	remaining: 2m 8s
# 162:	total: 24.9s	remaining: 2m 7s
# 163:	total: 25.1s	remaining: 2m 8s
# 164:	total: 25.2s	remaining: 2m 7s
# 165:	total: 25.4s	remaining: 2m 7s
# 166:	total: 25.5s	remaining: 2m 7s
# 167:	total: 25.7s	remaining: 2m 7s
# 168:	total: 25.8s	remaining: 2m 6s
# 169:	total: 25.9s	remaining: 2m 6s
# 170:	total: 26s	remaining: 2m 6s
# 171:	total: 26.2s	remaining: 2m 6s
# 172:	total: 26.4s	remaining: 2m 6s
# 173:	total: 26.5s	remaining: 2m 5s
# 174:	total: 26.6s	remaining: 2m 5s
# 175:	total: 26.8s	remaining: 2m 5s
# 176:	total: 26.9s	remaining: 2m 5s
# 177:	total: 27s	remaining: 2m 4s
# 178:	total: 27.1s	remaining: 2m 4s
# 179:	total: 27.3s	remaining: 2m 4s
# 180:	total: 27.5s	remaining: 2m 4s
# 181:	total: 27.6s	remaining: 2m 4s
# 182:	total: 27.8s	remaining: 2m 3s
# 183:	total: 27.9s	remaining: 2m 3s
# 184:	total: 28s	remaining: 2m 3s
# 185:	total: 28.2s	remaining: 2m 3s
# 186:	total: 28.3s	remaining: 2m 3s
# 187:	total: 28.4s	remaining: 2m 2s
# 188:	total: 28.7s	remaining: 2m 2s
# 189:	total: 28.8s	remaining: 2m 2s
# 190:	total: 28.9s	remaining: 2m 2s
# 191:	total: 29.1s	remaining: 2m 2s
# 192:	total: 29.2s	remaining: 2m 2s
# 193:	total: 29.3s	remaining: 2m 1s
# 194:	total: 29.4s	remaining: 2m 1s
# 195:	total: 29.6s	remaining: 2m 1s
# 196:	total: 29.8s	remaining: 2m 1s
# 197:	total: 30s	remaining: 2m 1s
# 198:	total: 30.1s	remaining: 2m 1s
# 199:	total: 30.2s	remaining: 2m
# 200:	total: 30.4s	remaining: 2m
# 201:	total: 30.5s	remaining: 2m
# 202:	total: 30.7s	remaining: 2m
# 203:	total: 30.9s	remaining: 2m
# 204:	total: 31.1s	remaining: 2m
# 205:	total: 31.2s	remaining: 2m
# 206:	total: 31.3s	remaining: 1m 59s
# 207:	total: 31.5s	remaining: 1m 59s
# 208:	total: 31.6s	remaining: 1m 59s
# 209:	total: 31.7s	remaining: 1m 59s
# 210:	total: 31.8s	remaining: 1m 59s
# 211:	total: 32s	remaining: 1m 58s
# 212:	total: 32.2s	remaining: 1m 58s
# 213:	total: 32.3s	remaining: 1m 58s
# 214:	total: 32.4s	remaining: 1m 58s
# 215:	total: 32.6s	remaining: 1m 58s
# 216:	total: 32.7s	remaining: 1m 57s
# 217:	total: 32.8s	remaining: 1m 57s
# 218:	total: 32.9s	remaining: 1m 57s
# 219:	total: 33.1s	remaining: 1m 57s
# 220:	total: 33.3s	remaining: 1m 57s
# 221:	total: 33.4s	remaining: 1m 57s
# 222:	total: 33.6s	remaining: 1m 56s
# 223:	total: 33.7s	remaining: 1m 56s
# 224:	total: 33.8s	remaining: 1m 56s
# 225:	total: 34s	remaining: 1m 56s
# 226:	total: 34.1s	remaining: 1m 56s
# 227:	total: 34.2s	remaining: 1m 55s
# 228:	total: 34.4s	remaining: 1m 55s
# 229:	total: 34.6s	remaining: 1m 55s
# 230:	total: 34.7s	remaining: 1m 55s
# 231:	total: 34.8s	remaining: 1m 55s
# 232:	total: 35s	remaining: 1m 55s
# 233:	total: 35.1s	remaining: 1m 54s
# 234:	total: 35.2s	remaining: 1m 54s
# 235:	total: 35.4s	remaining: 1m 54s
# 236:	total: 35.6s	remaining: 1m 54s
# 237:	total: 35.7s	remaining: 1m 54s
# 238:	total: 35.9s	remaining: 1m 54s
# 239:	total: 36s	remaining: 1m 53s
# 240:	total: 36.2s	remaining: 1m 53s
# 241:	total: 36.3s	remaining: 1m 53s
# 242:	total: 36.4s	remaining: 1m 53s
# 243:	total: 36.5s	remaining: 1m 53s
# 244:	total: 36.8s	remaining: 1m 53s
# 245:	total: 36.9s	remaining: 1m 53s
# 246:	total: 37s	remaining: 1m 52s
# 247:	total: 37.2s	remaining: 1m 52s
# 248:	total: 37.3s	remaining: 1m 52s
# 249:	total: 37.4s	remaining: 1m 52s
# 250:	total: 37.6s	remaining: 1m 52s
# 251:	total: 37.7s	remaining: 1m 52s
# 252:	total: 37.9s	remaining: 1m 51s
# 253:	total: 38.1s	remaining: 1m 51s
# 254:	total: 38.2s	remaining: 1m 51s
# 255:	total: 38.3s	remaining: 1m 51s
# 256:	total: 38.4s	remaining: 1m 51s
# 257:	total: 38.6s	remaining: 1m 50s
# 258:	total: 38.7s	remaining: 1m 50s
# 259:	total: 38.9s	remaining: 1m 50s
# 260:	total: 39.1s	remaining: 1m 50s
# 261:	total: 39.2s	remaining: 1m 50s
# 262:	total: 39.3s	remaining: 1m 50s
# 263:	total: 39.5s	remaining: 1m 50s
# 264:	total: 39.6s	remaining: 1m 49s
# 265:	total: 39.7s	remaining: 1m 49s
# 266:	total: 39.9s	remaining: 1m 49s
# 267:	total: 40.1s	remaining: 1m 49s
# 268:	total: 40.2s	remaining: 1m 49s
# 269:	total: 40.3s	remaining: 1m 49s
# 270:	total: 40.5s	remaining: 1m 48s
# 271:	total: 40.6s	remaining: 1m 48s
# 272:	total: 40.7s	remaining: 1m 48s
# 273:	total: 40.9s	remaining: 1m 48s
# 274:	total: 41s	remaining: 1m 48s
# 275:	total: 41.2s	remaining: 1m 48s
# 276:	total: 41.3s	remaining: 1m 47s
# 277:	total: 41.5s	remaining: 1m 47s
# 278:	total: 41.6s	remaining: 1m 47s
# 279:	total: 41.8s	remaining: 1m 47s
# 280:	total: 41.9s	remaining: 1m 47s
# 281:	total: 42s	remaining: 1m 47s
# 282:	total: 42.1s	remaining: 1m 46s
# 283:	total: 42.4s	remaining: 1m 46s
# 284:	total: 42.5s	remaining: 1m 46s
# 285:	total: 42.6s	remaining: 1m 46s
# 286:	total: 42.8s	remaining: 1m 46s
# 287:	total: 42.9s	remaining: 1m 46s
# 288:	total: 43s	remaining: 1m 45s
# 289:	total: 43.1s	remaining: 1m 45s
# 290:	total: 43.3s	remaining: 1m 45s
# 291:	total: 43.5s	remaining: 1m 45s
# 292:	total: 43.6s	remaining: 1m 45s
# 293:	total: 43.8s	remaining: 1m 45s
# 294:	total: 43.9s	remaining: 1m 44s
# 295:	total: 44s	remaining: 1m 44s
# 296:	total: 44.1s	remaining: 1m 44s
# 297:	total: 44.3s	remaining: 1m 44s
# 298:	total: 44.4s	remaining: 1m 44s
# 299:	total: 44.6s	remaining: 1m 44s
# 300:	total: 44.8s	remaining: 1m 43s
# 301:	total: 44.9s	remaining: 1m 43s
# 302:	total: 45s	remaining: 1m 43s
# 303:	total: 45.2s	remaining: 1m 43s
# 304:	total: 45.3s	remaining: 1m 43s
# 305:	total: 45.4s	remaining: 1m 43s
# 306:	total: 45.6s	remaining: 1m 42s
# 307:	total: 45.8s	remaining: 1m 42s
# 308:	total: 45.9s	remaining: 1m 42s
# 309:	total: 46.1s	remaining: 1m 42s
# 310:	total: 46.2s	remaining: 1m 42s
# 311:	total: 46.3s	remaining: 1m 42s
# 312:	total: 46.5s	remaining: 1m 41s
# 313:	total: 46.6s	remaining: 1m 41s
# 314:	total: 46.7s	remaining: 1m 41s
# 315:	total: 46.9s	remaining: 1m 41s
# 316:	total: 47s	remaining: 1m 41s
# 317:	total: 47.3s	remaining: 1m 41s
# 318:	total: 47.6s	remaining: 1m 41s
# 319:	total: 47.9s	remaining: 1m 41s
# 320:	total: 48.2s	remaining: 1m 41s
# 321:	total: 48.4s	remaining: 1m 41s
# 322:	total: 48.8s	remaining: 1m 42s
# 323:	total: 48.9s	remaining: 1m 42s
# 324:	total: 49.2s	remaining: 1m 42s
# 325:	total: 49.5s	remaining: 1m 42s
# 326:	total: 49.7s	remaining: 1m 42s
# 327:	total: 49.9s	remaining: 1m 42s
# 328:	total: 50.1s	remaining: 1m 42s
# 329:	total: 50.3s	remaining: 1m 42s
# 330:	total: 50.5s	remaining: 1m 42s
# 331:	total: 50.8s	remaining: 1m 42s
# 332:	total: 51s	remaining: 1m 42s
# 333:	total: 51.1s	remaining: 1m 41s
# 334:	total: 51.3s	remaining: 1m 41s
# 335:	total: 51.5s	remaining: 1m 41s
# 336:	total: 51.7s	remaining: 1m 41s
# 337:	total: 51.9s	remaining: 1m 41s
# 338:	total: 52.1s	remaining: 1m 41s
# 339:	total: 52.3s	remaining: 1m 41s
# 340:	total: 52.5s	remaining: 1m 41s
# 341:	total: 52.7s	remaining: 1m 41s
# 342:	total: 52.8s	remaining: 1m 41s
# 343:	total: 53.1s	remaining: 1m 41s
# 344:	total: 53.3s	remaining: 1m 41s
# 345:	total: 53.5s	remaining: 1m 41s
# 346:	total: 53.7s	remaining: 1m 41s
# 347:	total: 53.8s	remaining: 1m 40s
# 348:	total: 54s	remaining: 1m 40s
# 349:	total: 54.2s	remaining: 1m 40s
# ...
# 551:	total: 1m 21s	remaining: 1m 6s
# 552:	total: 1m 21s	remaining: 1m 6s
# 553:	total: 1m 22s	remaining: 1m 6s
# 554:	total: 1m 22s	remaining: 1m 5s
# 555:	total: 1m 22s	remaining: 1m 5s
# 556:	total: 1m 22s	remaining: 1m 5s
# 557:	total: 1m 22s	remaining: 1m 5s
# 558:	total: 1m 22s	remaining: 1m 5s
# 559:	total: 1m 22s	remaining: 1m 5s
# 560:	total: 1m 23s	remaining: 1m 5s
# 561:	total: 1m 23s	remaining: 1m 4s
# 562:	total: 1m 23s	remaining: 1m 4s
# 563:	total: 1m 23s	remaining: 1m 4s
# 564:	total: 1m 23s	remaining: 1m 4s
# 565:	total: 1m 23s	remaining: 1m 4s
# 566:	total: 1m 23s	remaining: 1m 4s
# 567:	total: 1m 24s	remaining: 1m 3s
# 568:	total: 1m 24s	remaining: 1m 3s
# 569:	total: 1m 24s	remaining: 1m 3s
# 570:	total: 1m 24s	remaining: 1m 3s
# 571:	total: 1m 24s	remaining: 1m 3s
# 572:	total: 1m 24s	remaining: 1m 3s
# 573:	total: 1m 25s	remaining: 1m 3s
# 574:	total: 1m 25s	remaining: 1m 3s
# 575:	total: 1m 25s	remaining: 1m 2s
# 576:	total: 1m 25s	remaining: 1m 2s
# 577:	total: 1m 25s	remaining: 1m 2s
# 578:	total: 1m 25s	remaining: 1m 2s
# 579:	total: 1m 25s	remaining: 1m 2s
# 580:	total: 1m 26s	remaining: 1m 2s
# 581:	total: 1m 26s	remaining: 1m 1s
# 582:	total: 1m 26s	remaining: 1m 1s
# 583:	total: 1m 26s	remaining: 1m 1s
# 584:	total: 1m 26s	remaining: 1m 1s
# 585:	total: 1m 26s	remaining: 1m 1s
# 586:	total: 1m 26s	remaining: 1m 1s
# 587:	total: 1m 27s	remaining: 1m 1s
# 588:	total: 1m 27s	remaining: 1m
# 589:	total: 1m 27s	remaining: 1m
# 590:	total: 1m 27s	remaining: 1m
# 591:	total: 1m 27s	remaining: 1m
# 592:	total: 1m 27s	remaining: 1m
# 593:	total: 1m 28s	remaining: 1m
# 594:	total: 1m 28s	remaining: 60s
# 595:	total: 1m 28s	remaining: 59.8s
# 596:	total: 1m 28s	remaining: 59.7s
# 597:	total: 1m 28s	remaining: 59.5s
# 598:	total: 1m 28s	remaining: 59.4s
# 599:	total: 1m 28s	remaining: 59.2s
# 600:	total: 1m 29s	remaining: 59.1s
# 601:	total: 1m 29s	remaining: 58.9s
# 602:	total: 1m 29s	remaining: 58.8s
# 603:	total: 1m 29s	remaining: 58.6s
# 604:	total: 1m 29s	remaining: 58.5s
# 605:	total: 1m 29s	remaining: 58.3s
# 606:	total: 1m 29s	remaining: 58.2s
# 607:	total: 1m 30s	remaining: 58s
# 608:	total: 1m 30s	remaining: 57.9s
# 609:	total: 1m 30s	remaining: 57.7s
# 610:	total: 1m 30s	remaining: 57.5s
# 611:	total: 1m 30s	remaining: 57.4s
# 612:	total: 1m 30s	remaining: 57.3s
# 613:	total: 1m 30s	remaining: 57.1s
# 614:	total: 1m 31s	remaining: 57s
# 615:	total: 1m 31s	remaining: 56.8s
# 616:	total: 1m 31s	remaining: 56.7s
# 617:	total: 1m 31s	remaining: 56.5s
# 618:	total: 1m 31s	remaining: 56.4s
# 619:	total: 1m 31s	remaining: 56.2s
# 620:	total: 1m 31s	remaining: 56.1s
# 621:	total: 1m 31s	remaining: 55.9s
# 622:	total: 1m 32s	remaining: 55.8s
# 623:	total: 1m 32s	remaining: 55.6s
# 624:	total: 1m 32s	remaining: 55.4s
# 625:	total: 1m 32s	remaining: 55.3s
# 626:	total: 1m 32s	remaining: 55.1s
# 627:	total: 1m 32s	remaining: 55s
# 628:	total: 1m 32s	remaining: 54.8s
# 629:	total: 1m 33s	remaining: 54.6s
# 630:	total: 1m 33s	remaining: 54.5s
# 631:	total: 1m 33s	remaining: 54.4s
# 632:	total: 1m 33s	remaining: 54.2s
# 633:	total: 1m 33s	remaining: 54s
# 634:	total: 1m 33s	remaining: 53.9s
# 635:	total: 1m 33s	remaining: 53.7s
# 636:	total: 1m 34s	remaining: 53.6s
# 637:	total: 1m 34s	remaining: 53.4s
# 638:	total: 1m 34s	remaining: 53.3s
# 639:	total: 1m 34s	remaining: 53.1s
# 640:	total: 1m 34s	remaining: 53s
# 641:	total: 1m 34s	remaining: 52.8s
# 642:	total: 1m 34s	remaining: 52.7s
# 643:	total: 1m 35s	remaining: 52.5s
# 644:	total: 1m 35s	remaining: 52.4s
# 645:	total: 1m 35s	remaining: 52.2s
# 646:	total: 1m 35s	remaining: 52.1s
# 647:	total: 1m 35s	remaining: 51.9s
# 648:	total: 1m 35s	remaining: 51.8s
# 649:	total: 1m 35s	remaining: 51.6s
# 650:	total: 1m 35s	remaining: 51.5s
# 651:	total: 1m 36s	remaining: 51.3s
# 652:	total: 1m 36s	remaining: 51.2s
# 653:	total: 1m 36s	remaining: 51s
# 654:	total: 1m 36s	remaining: 50.9s
# 655:	total: 1m 36s	remaining: 50.7s
# 656:	total: 1m 36s	remaining: 50.6s
# 657:	total: 1m 36s	remaining: 50.4s
# 658:	total: 1m 37s	remaining: 50.2s
# 659:	total: 1m 37s	remaining: 50.1s
# 660:	total: 1m 37s	remaining: 50s
# 661:	total: 1m 37s	remaining: 49.8s
# 662:	total: 1m 37s	remaining: 49.7s
# 663:	total: 1m 37s	remaining: 49.5s
# 664:	total: 1m 38s	remaining: 49.4s
# 665:	total: 1m 38s	remaining: 49.2s
# 666:	total: 1m 38s	remaining: 49.1s
# 667:	total: 1m 38s	remaining: 48.9s
# 668:	total: 1m 38s	remaining: 48.8s
# 669:	total: 1m 38s	remaining: 48.6s
# 670:	total: 1m 38s	remaining: 48.5s
# 671:	total: 1m 38s	remaining: 48.3s
# 672:	total: 1m 39s	remaining: 48.1s
# 673:	total: 1m 39s	remaining: 48s
# 674:	total: 1m 39s	remaining: 47.8s
# 675:	total: 1m 39s	remaining: 47.7s
# 676:	total: 1m 39s	remaining: 47.5s
# 677:	total: 1m 39s	remaining: 47.4s
# 678:	total: 1m 39s	remaining: 47.2s
# 679:	total: 1m 40s	remaining: 47.1s
# 680:	total: 1m 40s	remaining: 46.9s
# 681:	total: 1m 40s	remaining: 46.8s
# 682:	total: 1m 40s	remaining: 46.6s
# 683:	total: 1m 40s	remaining: 46.5s
# 684:	total: 1m 40s	remaining: 46.3s
# 685:	total: 1m 40s	remaining: 46.2s
# 686:	total: 1m 41s	remaining: 46s
# 687:	total: 1m 41s	remaining: 45.9s
# 688:	total: 1m 41s	remaining: 45.7s
# 689:	total: 1m 41s	remaining: 45.6s
# 690:	total: 1m 41s	remaining: 45.4s
# 691:	total: 1m 41s	remaining: 45.3s
# 692:	total: 1m 41s	remaining: 45.1s
# 693:	total: 1m 42s	remaining: 45s
# 694:	total: 1m 42s	remaining: 44.8s
# 695:	total: 1m 42s	remaining: 44.7s
# 696:	total: 1m 42s	remaining: 44.5s
# 697:	total: 1m 42s	remaining: 44.4s
# 698:	total: 1m 42s	remaining: 44.2s
# 699:	total: 1m 42s	remaining: 44.1s
# 700:	total: 1m 42s	remaining: 43.9s
# 701:	total: 1m 43s	remaining: 43.8s
# 702:	total: 1m 43s	remaining: 43.6s
# 703:	total: 1m 43s	remaining: 43.5s
# 704:	total: 1m 43s	remaining: 43.3s
# 705:	total: 1m 43s	remaining: 43.2s
# 706:	total: 1m 43s	remaining: 43s
# 707:	total: 1m 43s	remaining: 42.9s
# 708:	total: 1m 44s	remaining: 42.7s
# 709:	total: 1m 44s	remaining: 42.6s
# 710:	total: 1m 44s	remaining: 42.4s
# 711:	total: 1m 44s	remaining: 42.3s
# 712:	total: 1m 44s	remaining: 42.1s
# 713:	total: 1m 44s	remaining: 42s
# 714:	total: 1m 45s	remaining: 41.9s
# 715:	total: 1m 45s	remaining: 41.8s
# 716:	total: 1m 45s	remaining: 41.6s
# 717:	total: 1m 45s	remaining: 41.5s
# 718:	total: 1m 45s	remaining: 41.4s
# 719:	total: 1m 46s	remaining: 41.3s
# 720:	total: 1m 46s	remaining: 41.1s
# 721:	total: 1m 46s	remaining: 41s
# 722:	total: 1m 46s	remaining: 40.9s
# 723:	total: 1m 46s	remaining: 40.7s
# 724:	total: 1m 47s	remaining: 40.6s
# 725:	total: 1m 47s	remaining: 40.5s
# 726:	total: 1m 47s	remaining: 40.3s
# 727:	total: 1m 47s	remaining: 40.2s
# 728:	total: 1m 47s	remaining: 40s
# 729:	total: 1m 47s	remaining: 39.9s
# 730:	total: 1m 47s	remaining: 39.7s
# 731:	total: 1m 48s	remaining: 39.6s
# 732:	total: 1m 48s	remaining: 39.4s
# 733:	total: 1m 48s	remaining: 39.3s
# 734:	total: 1m 48s	remaining: 39.1s
# 735:	total: 1m 48s	remaining: 38.9s
# 736:	total: 1m 48s	remaining: 38.8s
# 737:	total: 1m 48s	remaining: 38.6s
# 738:	total: 1m 48s	remaining: 38.5s
# 739:	total: 1m 49s	remaining: 38.3s
# 740:	total: 1m 49s	remaining: 38.2s
# 741:	total: 1m 49s	remaining: 38.1s
# 742:	total: 1m 49s	remaining: 37.9s
# 743:	total: 1m 49s	remaining: 37.8s
# 744:	total: 1m 49s	remaining: 37.6s
# 745:	total: 1m 50s	remaining: 37.5s
# 746:	total: 1m 50s	remaining: 37.3s
# 747:	total: 1m 50s	remaining: 37.2s
# 748:	total: 1m 50s	remaining: 37s
# 749:	total: 1m 50s	remaining: 36.9s
# 750:	total: 1m 50s	remaining: 36.7s
# 751:	total: 1m 50s	remaining: 36.6s
# 752:	total: 1m 51s	remaining: 36.4s
# 753:	total: 1m 51s	remaining: 36.3s
# 754:	total: 1m 51s	remaining: 36.1s
# 755:	total: 1m 51s	remaining: 36s
# 756:	total: 1m 51s	remaining: 35.8s
# 757:	total: 1m 51s	remaining: 35.7s
# 758:	total: 1m 51s	remaining: 35.5s
# 759:	total: 1m 52s	remaining: 35.4s
# 760:	total: 1m 52s	remaining: 35.2s
# 761:	total: 1m 52s	remaining: 35.1s
# 762:	total: 1m 52s	remaining: 34.9s
# 763:	total: 1m 52s	remaining: 34.8s
# 764:	total: 1m 52s	remaining: 34.6s
# 765:	total: 1m 52s	remaining: 34.5s
# 766:	total: 1m 52s	remaining: 34.3s
# 767:	total: 1m 53s	remaining: 34.2s
# 768:	total: 1m 53s	remaining: 34s
# 769:	total: 1m 53s	remaining: 33.9s
# 770:	total: 1m 53s	remaining: 33.7s
# 771:	total: 1m 53s	remaining: 33.6s
# 772:	total: 1m 53s	remaining: 33.4s
# 773:	total: 1m 53s	remaining: 33.3s
# 774:	total: 1m 54s	remaining: 33.1s
# 775:	total: 1m 54s	remaining: 33s
# 776:	total: 1m 54s	remaining: 32.8s
# 777:	total: 1m 54s	remaining: 32.7s
# 778:	total: 1m 54s	remaining: 32.5s
# 779:	total: 1m 54s	remaining: 32.4s
# 780:	total: 1m 54s	remaining: 32.2s
# 781:	total: 1m 55s	remaining: 32.1s
# 782:	total: 1m 55s	remaining: 31.9s
# 783:	total: 1m 55s	remaining: 31.8s
# 784:	total: 1m 55s	remaining: 31.6s
# 785:	total: 1m 55s	remaining: 31.5s
# 786:	total: 1m 55s	remaining: 31.3s
# 787:	total: 1m 55s	remaining: 31.2s
# 788:	total: 1m 56s	remaining: 31.1s
# 789:	total: 1m 56s	remaining: 30.9s
# 790:	total: 1m 56s	remaining: 30.7s
# 791:	total: 1m 56s	remaining: 30.6s
# 792:	total: 1m 56s	remaining: 30.5s
# 793:	total: 1m 56s	remaining: 30.3s
# 794:	total: 1m 56s	remaining: 30.1s
# 795:	total: 1m 57s	remaining: 30s
# 796:	total: 1m 57s	remaining: 29.9s
# 797:	total: 1m 57s	remaining: 29.7s
# 798:	total: 1m 57s	remaining: 29.6s
# 799:	total: 1m 57s	remaining: 29.4s
# 800:	total: 1m 57s	remaining: 29.3s
# 801:	total: 1m 57s	remaining: 29.1s
# 802:	total: 1m 58s	remaining: 28.9s
# 803:	total: 1m 58s	remaining: 28.8s
# 804:	total: 1m 58s	remaining: 28.7s
# 805:	total: 1m 58s	remaining: 28.5s
# 806:	total: 1m 58s	remaining: 28.4s
# 807:	total: 1m 58s	remaining: 28.2s
# 808:	total: 1m 58s	remaining: 28.1s
# 809:	total: 1m 59s	remaining: 27.9s
# 810:	total: 1m 59s	remaining: 27.8s
# 811:	total: 1m 59s	remaining: 27.6s
# 812:	total: 1m 59s	remaining: 27.5s
# 813:	total: 1m 59s	remaining: 27.3s
# 814:	total: 1m 59s	remaining: 27.2s
# 815:	total: 1m 59s	remaining: 27s
# 816:	total: 2m	remaining: 26.9s
# 817:	total: 2m	remaining: 26.7s
# 818:	total: 2m	remaining: 26.6s
# 819:	total: 2m	remaining: 26.4s
# 820:	total: 2m	remaining: 26.3s
# 821:	total: 2m	remaining: 26.2s
# 822:	total: 2m	remaining: 26s
# 823:	total: 2m 1s	remaining: 25.9s
# 824:	total: 2m 1s	remaining: 25.7s
# 825:	total: 2m 1s	remaining: 25.6s
# 826:	total: 2m 1s	remaining: 25.4s
# 827:	total: 2m 1s	remaining: 25.3s
# 828:	total: 2m 1s	remaining: 25.1s
# 829:	total: 2m 1s	remaining: 25s
# 830:	total: 2m 2s	remaining: 24.8s
# 831:	total: 2m 2s	remaining: 24.7s
# 832:	total: 2m 2s	remaining: 24.5s
# 833:	total: 2m 2s	remaining: 24.4s
# 834:	total: 2m 2s	remaining: 24.2s
# 835:	total: 2m 2s	remaining: 24.1s
# 836:	total: 2m 2s	remaining: 23.9s
# 837:	total: 2m 3s	remaining: 23.8s
# 838:	total: 2m 3s	remaining: 23.6s
# 839:	total: 2m 3s	remaining: 23.5s
# 840:	total: 2m 3s	remaining: 23.3s
# 841:	total: 2m 3s	remaining: 23.2s
# 842:	total: 2m 3s	remaining: 23s
# 843:	total: 2m 3s	remaining: 22.9s
# 844:	total: 2m 4s	remaining: 22.8s
# 845:	total: 2m 4s	remaining: 22.6s
# 846:	total: 2m 4s	remaining: 22.5s
# 847:	total: 2m 4s	remaining: 22.3s
# 848:	total: 2m 4s	remaining: 22.2s
# 849:	total: 2m 4s	remaining: 22s
# 850:	total: 2m 4s	remaining: 21.9s
# 851:	total: 2m 5s	remaining: 21.7s
# 852:	total: 2m 5s	remaining: 21.6s
# 853:	total: 2m 5s	remaining: 21.4s
# 854:	total: 2m 5s	remaining: 21.3s
# 855:	total: 2m 5s	remaining: 21.1s
# 856:	total: 2m 5s	remaining: 21s
# 857:	total: 2m 5s	remaining: 20.8s
# 858:	total: 2m 6s	remaining: 20.7s
# 859:	total: 2m 6s	remaining: 20.5s
# 860:	total: 2m 6s	remaining: 20.4s
# 861:	total: 2m 6s	remaining: 20.2s
# 862:	total: 2m 6s	remaining: 20.1s
# 863:	total: 2m 6s	remaining: 19.9s
# 864:	total: 2m 6s	remaining: 19.8s
# 865:	total: 2m 6s	remaining: 19.6s
# 866:	total: 2m 7s	remaining: 19.5s
# 867:	total: 2m 7s	remaining: 19.4s
# 868:	total: 2m 7s	remaining: 19.2s
# 869:	total: 2m 7s	remaining: 19.1s
# 870:	total: 2m 7s	remaining: 18.9s
# 871:	total: 2m 7s	remaining: 18.8s
# 872:	total: 2m 7s	remaining: 18.6s
# 873:	total: 2m 8s	remaining: 18.5s
# 874:	total: 2m 8s	remaining: 18.3s
# 875:	total: 2m 8s	remaining: 18.2s
# 876:	total: 2m 8s	remaining: 18s
# 877:	total: 2m 8s	remaining: 17.9s
# 878:	total: 2m 8s	remaining: 17.7s
# 879:	total: 2m 8s	remaining: 17.6s
# 880:	total: 2m 9s	remaining: 17.4s
# 881:	total: 2m 9s	remaining: 17.3s
# 882:	total: 2m 9s	remaining: 17.1s
# 883:	total: 2m 9s	remaining: 17s
# 884:	total: 2m 9s	remaining: 16.8s
# 885:	total: 2m 9s	remaining: 16.7s
# 886:	total: 2m 9s	remaining: 16.6s
# 887:	total: 2m 10s	remaining: 16.4s
# 888:	total: 2m 10s	remaining: 16.3s
# 889:	total: 2m 10s	remaining: 16.1s
# 890:	total: 2m 10s	remaining: 16s
# 891:	total: 2m 10s	remaining: 15.8s
# 892:	total: 2m 10s	remaining: 15.7s
# 893:	total: 2m 10s	remaining: 15.5s
# 894:	total: 2m 11s	remaining: 15.4s
# 895:	total: 2m 11s	remaining: 15.2s
# 896:	total: 2m 11s	remaining: 15.1s
# 897:	total: 2m 11s	remaining: 15s
# 898:	total: 2m 11s	remaining: 14.8s
# 899:	total: 2m 12s	remaining: 14.7s
# 900:	total: 2m 12s	remaining: 14.5s
# 901:	total: 2m 12s	remaining: 14.4s
# 902:	total: 2m 12s	remaining: 14.3s
# 903:	total: 2m 12s	remaining: 14.1s
# 904:	total: 2m 13s	remaining: 14s
# 905:	total: 2m 13s	remaining: 13.8s
# 906:	total: 2m 13s	remaining: 13.7s
# 907:	total: 2m 13s	remaining: 13.5s
# 908:	total: 2m 13s	remaining: 13.4s
# 909:	total: 2m 13s	remaining: 13.2s
# 910:	total: 2m 14s	remaining: 13.1s
# 911:	total: 2m 14s	remaining: 12.9s
# 912:	total: 2m 14s	remaining: 12.8s
# 913:	total: 2m 14s	remaining: 12.6s
# 914:	total: 2m 14s	remaining: 12.5s
# 915:	total: 2m 14s	remaining: 12.4s
# 916:	total: 2m 14s	remaining: 12.2s
# 917:	total: 2m 14s	remaining: 12.1s
# 918:	total: 2m 15s	remaining: 11.9s
# 919:	total: 2m 15s	remaining: 11.8s
# 920:	total: 2m 15s	remaining: 11.6s
# 921:	total: 2m 15s	remaining: 11.5s
# 922:	total: 2m 15s	remaining: 11.3s
# 923:	total: 2m 15s	remaining: 11.2s
# 924:	total: 2m 15s	remaining: 11s
# 925:	total: 2m 16s	remaining: 10.9s
# 926:	total: 2m 16s	remaining: 10.7s
# 927:	total: 2m 16s	remaining: 10.6s
# 928:	total: 2m 16s	remaining: 10.4s
# 929:	total: 2m 16s	remaining: 10.3s
# 930:	total: 2m 16s	remaining: 10.1s
# 931:	total: 2m 16s	remaining: 9.99s
# 932:	total: 2m 17s	remaining: 9.85s
# 933:	total: 2m 17s	remaining: 9.7s
# 934:	total: 2m 17s	remaining: 9.55s
# 935:	total: 2m 17s	remaining: 9.4s
# 936:	total: 2m 17s	remaining: 9.26s
# 937:	total: 2m 17s	remaining: 9.11s
# 938:	total: 2m 17s	remaining: 8.96s
# 939:	total: 2m 18s	remaining: 8.82s
# 940:	total: 2m 18s	remaining: 8.67s
# 941:	total: 2m 18s	remaining: 8.52s
# 942:	total: 2m 18s	remaining: 8.37s
# 943:	total: 2m 18s	remaining: 8.23s
# 944:	total: 2m 18s	remaining: 8.08s
# 945:	total: 2m 18s	remaining: 7.93s
# 946:	total: 2m 19s	remaining: 7.78s
# 947:	total: 2m 19s	remaining: 7.64s
# 948:	total: 2m 19s	remaining: 7.49s
# 949:	total: 2m 19s	remaining: 7.34s
# 950:	total: 2m 19s	remaining: 7.2s
# 951:	total: 2m 19s	remaining: 7.05s
# 952:	total: 2m 19s	remaining: 6.9s
# 953:	total: 2m 20s	remaining: 6.76s
# 954:	total: 2m 20s	remaining: 6.61s
# 955:	total: 2m 20s	remaining: 6.46s
# 956:	total: 2m 20s	remaining: 6.32s
# 957:	total: 2m 20s	remaining: 6.17s
# 958:	total: 2m 20s	remaining: 6.02s
# 959:	total: 2m 21s	remaining: 5.88s
# 960:	total: 2m 21s	remaining: 5.73s
# 961:	total: 2m 21s	remaining: 5.58s
# 962:	total: 2m 21s	remaining: 5.43s
# 963:	total: 2m 21s	remaining: 5.29s
# 964:	total: 2m 21s	remaining: 5.14s
# 965:	total: 2m 21s	remaining: 4.99s
# 966:	total: 2m 21s	remaining: 4.84s
# 967:	total: 2m 22s	remaining: 4.7s
# 968:	total: 2m 22s	remaining: 4.55s
# 969:	total: 2m 22s	remaining: 4.4s
# 970:	total: 2m 22s	remaining: 4.26s
# 971:	total: 2m 22s	remaining: 4.11s
# 972:	total: 2m 22s	remaining: 3.96s
# 973:	total: 2m 22s	remaining: 3.82s
# 974:	total: 2m 23s	remaining: 3.67s
# 975:	total: 2m 23s	remaining: 3.53s
# 976:	total: 2m 23s	remaining: 3.38s
# 977:	total: 2m 23s	remaining: 3.23s
# 978:	total: 2m 24s	remaining: 3.09s
# 979:	total: 2m 24s	remaining: 2.94s
# 980:	total: 2m 24s	remaining: 2.8s
# 981:	total: 2m 24s	remaining: 2.65s
# 982:	total: 2m 24s	remaining: 2.5s
# 983:	total: 2m 25s	remaining: 2.36s
# 984:	total: 2m 25s	remaining: 2.21s
# 985:	total: 2m 25s	remaining: 2.06s
# 986:	total: 2m 25s	remaining: 1.92s
# 987:	total: 2m 25s	remaining: 1.77s
# 988:	total: 2m 26s	remaining: 1.62s
# 989:	total: 2m 26s	remaining: 1.48s
# 990:	total: 2m 26s	remaining: 1.33s
# 991:	total: 2m 26s	remaining: 1.18s
# 992:	total: 2m 26s	remaining: 1.03s
# 993:	total: 2m 26s	remaining: 886ms
# 994:	total: 2m 26s	remaining: 738ms
# 995:	total: 2m 27s	remaining: 591ms
# 996:	total: 2m 27s	remaining: 443ms
# 997:	total: 2m 27s	remaining: 295ms
# 998:	total: 2m 27s	remaining: 148ms
# 999:	total: 2m 27s	remaining: 0us

# %%
score
# Out:
# 0.7234372617895846

# %% [markdown]
# ### Первые выводы
#
# 1. Для обучения моделей градиентного бустинга понадобилось избавиться от пропусков. Некоторые из них несли смысл - они обозначали не отсутвие информации об игре (как обычно), а отсутвие самого события. Например признак first_blood_team обозначает команду, совершивую "первую кровь", а пропуск в этом признаке - ни одна команда не сделала это в первые пять минут. Все остальные признаки категории first_blood имеют тот же смысл.
#
#   Если заменить пропуски first_blood на очень большое или маленькое число, то модель будет показывать такое же качество, как и при замене на 0, а обучаться намного дольше (выяснилось опытным путем). Поэтому все пропуски были заменены на 0. В данных также были лишние признаки, содержащие информацию, неизвестную в первые пять минут игры. В каком-то смысле эти признаки - утечка данных, поэтому для обучения они не нужны, и мы их удалили.
#
#
# 2. Для обучения из данных был извлечен столбец radiant_win, являющийся целевой переменной.
#
# 3-4. Модель Gradient Boosting Classifier показала результат roc_auc = 0,69 при 30 деревьях, при этом качество прогноза увеличивалось при увеличении числа деревьев. Обучение на 30 деревьях длилось 6 минут. Для того чтобы ускорить обучение при большем количестве деревьев, можно отрегулировать другие гиперпараметры. Например, ограничить глубину деревьев или увеличить шаг.
#
# Для сравнения была также обучена модель CatBoost. Её обучение занимает больше времени, но дает лучший результат. Ее метрика ROC AUC равна 72.

# %% [markdown]
# ### Логистическая регрессия

# %%
def log_regr(features, target):
    """
    Функция принимает на вход данные,
    масштабирует их, строит модель логистической регрессии
    и иллюстрирует качество модели при заданном параметре регуляризации
    """
    
    scaler = StandardScaler()
    features_scaled = scaler.fit_transform(features)
    cv = KFold(shuffle=True)
    for c in np.linspace(1, 5, 10): # подбор параметра C
        log_reg = LogisticRegression(max_iter=100, C=c)
        log_reg.fit(features_scaled, target)
        score = cross_val_score(log_reg, features_scaled, target, cv=cv, scoring='roc_auc').mean()
        print('C:', round(c, 2), '|', 'Score:', round(score, 2))

# %%
log_regr(features, target)
# Out:
# C: 1.0 | Score: 0.72
# C: 1.44 | Score: 0.72
# C: 1.89 | Score: 0.72
# C: 2.33 | Score: 0.72
# C: 2.78 | Score: 0.72
# C: 3.22 | Score: 0.72
# C: 3.67 | Score: 0.72
# C: 4.11 | Score: 0.72
# C: 4.56 | Score: 0.72
# C: 5.0 | Score: 0.72

# %%
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# %%
# %%time

log_reg = LogisticRegression(max_iter=100)
log_reg.fit(features_scaled, target)
# Out:
# Wall time: 2.06 s
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# > Логистическая регрессия работает гораздо быстрее градиентоного бустинга и дает лучший результат - 0,72 ROC AUC за 2 секунды. Однако, отставание градиентного бустинга скорее всего объясняется нетщательным подбором паратеров. Более качественная оптимизация параметров при построении модели бустинга дала бы ей больший результат.

# %% [markdown]
# ### Удаление категориальных признаков

# %% [markdown]
# Среди признаков в выборке есть категориальные, которые мы использовали как числовые, что вряд ли является хорошей идеей. Категориальных признаков в этой задаче одиннадцать: lobby_type и r1_hero, r2_hero, ..., r5_hero, d1_hero, d2_hero, ..., d5_hero. Уберите их из выборки, и проведите кросс-валидацию для логистической регрессии на новой выборке с подбором лучшего параметра регуляризации. Изменилось ли качество? Чем вы можете это объяснить?

# %%
features
# Out:
#           start_time  lobby_type  r1_hero  r1_level  r1_xp  r1_gold  r1_lh  \
# match_id
# 0         1430198770           7       11         5   2098     1489     20
# 1         1430220345           0       42         4   1188     1033      9
# 2         1430227081           7       33         4   1319     1270     22
# 3         1430263531           1       29         4   1779     1056     14
# 4         1430282290           7       13         4   1431     1090      8
# ...              ...         ...      ...       ...    ...      ...    ...
# 114402    1450265551           1       47         4   1706     1198     17
# 114403    1450277704           0       43         4   1793     1416     17
# 114404    1450291848           1       98         4   1399      540      1
# 114405    1450292986           1      100         3   1135      766      6
# 114406    1450313370           7       50         3   1053      799      7
#
#           r1_kills  r1_deaths  r1_items  ...  radiant_ward_sentry_count  \
# match_id                                 ...
# 0                0          0         7  ...                          0
# 1                0          1        12  ...                          0
# 2                0          0        12  ...                          1
# 3                0          0         5  ...                          0
# 4                1          0         8  ...                          0
# ...            ...        ...       ...  ...                        ...
# 114402           0          1         8  ...                          0
# 114403           0          1         5  ...                          0
# 114404           0          0         5  ...                          2
# 114405           0          2         6  ...                          0
# 114406           0          0         7  ...                          0
#
#           radiant_first_ward_time  dire_bottle_time  dire_courier_time  \
# match_id
# 0                            35.0             103.0              -84.0
# 1                           -20.0             149.0              -84.0
# 2                           -39.0              45.0              -77.0
# 3                           -30.0             124.0              -80.0
# 4                            46.0             182.0              -80.0
# ...                           ...               ...                ...
# 114402                      -29.0             180.0              -76.0
# 114403                       -5.0               0.0              -82.0
# 114404                      -32.0             249.0              -70.0
# 114405                      -21.0             254.0              -85.0
# 114406                      -36.0             131.0              -59.0
#
#           dire_flying_courier_time  dire_tpscroll_count  dire_boots_count  \
# match_id
# 0                            221.0                    3                 4
# 1                            195.0                    5                 4
# 2                            221.0                    3                 4
# 3                            184.0                    0                 4
# 4                            225.0                    6                 3
# ...                            ...                  ...               ...
# 114402                       180.0                    3                 4
# 114403                         0.0                    4                 3
# 114404                         0.0                    1                 1
# 114405                       183.0                    5                 3
# 114406                         0.0                    5                 3
#
#           dire_ward_observer_count  dire_ward_sentry_count  \
# match_id
# 0                                2                       2
# 1                                3                       1
# 2                                3                       1
# 3                                2                       0
# 4                                3                       0
# ...                            ...                     ...
# 114402                           3                       0
# 114403                           2                       0
# 114404                           3                       1
# 114405                           3                       1
# 114406                           2                       0
#
#           dire_first_ward_time
# match_id
# 0                        -52.0
# 1                         -5.0
# 2                         13.0
# 3                         27.0
# 4                        -16.0
# ...                        ...
# 114402                   -24.0
# 114403                   -17.0
# 114404                   -15.0
# 114405                   -42.0
# 114406                   -39.0
#
# [97230 rows x 102 columns]

# %%
categorical = ["lobby_type", "r1_hero", "r2_hero", "r3_hero", "r4_hero", "r5_hero", 
              "d1_hero", "d2_hero", "d3_hero", "d4_hero", "d5_hero"]

# %%
features_without_heros = features.drop(categorical, axis=1)

# %%
log_regr(features_without_heros, target)
# Out:
# C: 1.0 | Score: 0.72
# C: 1.44 | Score: 0.72
# C: 1.89 | Score: 0.72
# C: 2.33 | Score: 0.72
# C: 2.78 | Score: 0.72
# C: 3.22 | Score: 0.72
# C: 3.67 | Score: 0.72
# C: 4.11 | Score: 0.72
# C: 4.56 | Score: 0.72
# C: 5.0 | Score: 0.72

# %% [markdown]
# > Качество модели совсем не изменилось. Это связано с тем, что категориальные (хоть и выраженные числами) признаки требуют кодирования, иначе модель воспринимает их как количественные и считает, что большее число, обозначающее одну группу объектов важнее меньшего, обозначающего другую группу. Для наших данных это неверный подход и модель не извлекла нужной информации из категориальных признаков, поэтому дала этим признакам малый вес.

# %% [markdown]
# #### Количество героев

# %% [markdown]
# На предыдущем шаге мы исключили из выборки признаки rM_hero и dM_hero, которые показывают, какие именно герои играли за каждую команду. Это важные признаки — герои имеют разные характеристики, и некоторые из них выигрывают чаще, чем другие. Выясните из данных, сколько различных идентификаторов героев существует в данной игре.

# %%
len(features.r1_hero.unique())
# Out:
# 108

# %%
max(features.r1_hero.unique())
# Out:
# 112

# %% [markdown]
# > В данных содержится информация о 108 игроках, при этом максимальный инедекс игрока - 112. Это значит, что согласно нашим данным 4 игрока в матчах не ипользуется вообще. Возможны три варианта: герои слабые и непопулярные или постоянно забанены противником из-за того что очень сильные, или с выборкой что-то не так.

# %% [markdown]
# #### Кодирование с помощью мешка слов

# %%
#  к од для формирования "мешка слов" по героям

def encoding(data):
    X_pick = np.zeros((data.shape[0], 112))
    for i, match_id in enumerate(data.index):
        for p in range(5):
            r_hero = 'r%d_hero' % (p+1)
            d_hero = 'd%d_hero' % (p+1)

            hero_name_r = data.loc[match_id, r_hero]
            hero_name_d = data.loc[match_id, d_hero]

            X_pick[i, data.loc[match_id, r_hero]-1] = 1
            X_pick[i, data.loc[match_id, d_hero]-1] = -1
    return X_pick

# %%
X_pick = encoding(features)

# %%
features_scaled_categorized = np.hstack((features_without_heros, X_pick))

# %%
features_scaled_categorized
# Out:
# array([[-2.54436416,  1.40080818,  1.52597175, ...,  0.        ,
#          0.        ,  0.        ],
#        [-2.54045236,  0.50131354, -0.08013929, ...,  0.        ,
#          0.        ,  0.        ],
#        [-2.53923104,  0.50131354,  0.1510701 , ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 1.09874571,  0.50131354,  0.29226667, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 1.09895204, -0.39818111, -0.17368203, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.1026479 , -0.39818111, -0.31840851, ...,  0.        ,
#          0.        , -1.        ]])

# %%
log_regr(features_scaled_categorized, target)
# Out:
# C: 1.0 | Score: 0.75
# C: 1.44 | Score: 0.75
# C: 1.89 | Score: 0.75
# C: 2.33 | Score: 0.75
# C: 2.78 | Score: 0.75
# C: 3.22 | Score: 0.75
# C: 3.67 | Score: 0.75
# C: 4.11 | Score: 0.75
# C: 4.56 | Score: 0.75
# C: 5.0 | Score: 0.75

# %% [markdown]
# > Качество модели значительно улучшилось: кодирование и масштабирование признаков помогли модели справиться с прогнозированием исхода матча.

# %% [markdown]
# ### Прогнозирование на тестовой выборке

# %%
X_pick_test = encoding(test) 
test_scaled_and_categorized = np.hstack((scaler.transform(test.drop(categorical, axis=1)), 
                                                  X_pick_test))

# %%
log_reg = LogisticRegression()
log_reg.fit(features_scaled_categorized, target)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = log_reg.predict(test_scaled_and_categorized)

# %%
predictions_proba = log_reg.predict_proba(test_scaled_and_categorized)[:, 1]

# %%
print('Минимальное значение прогноза:', round(min(predictions_proba), 4))
print('Максимальное значение прогноза:', round(max(predictions_proba), 4))
# Out:
# Минимальное значение прогноза: 0.0085
# Максимальное значение прогноза: 0.9964

# %% [markdown]
# Задача классификации решалась путем построения моделей градиентного бустинга и логистической регресии. На начальном этапе модели показывали идентичный результат, с той лишь разницей, что логистическая регрессия справлялась с обучением гораздо быстрее. После обработки данных: масштабирования количественнных признаков и кодирования категориальных ROC AUC лог.регрессии стал еще выше; значение параметра регуляризации не меняло модели из-за того, что данных очень много и модель не переобучается, поэтому регуляризация бесполезна. Предсказание строилось с помощью модели логистической регрессии.
